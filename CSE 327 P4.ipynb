# %% [markdown]
# The block below imports a necessary module and checks if you are in the right directory. If you do not see a list of python files when you run the block, please make sure you have uploaded the zip file and unzipped it.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# If you want to create a random knowledge base, run the following code.
#
# Creates the files:
#
# * randomKB.txt - A random KB generated using 10 predicates and 100 constants.
# * vocab.pkl - Indexes the full set of predicates, constants and variables used by the knowledge base.

# %%
# !python kbencoder.py --generate_kb --new_vocab --save_vocab
# !head randomKB.txt
# Out:
# Classes: 1000000000.0
# Max arity: 4
# KB generated (150)
# p0(a95, a1).
# p5(a38).
# p4(a1, a31, a13, a10).
# p3(a75, a51).
# p5(a29).
# p5(a0).
# p0(a40, a36).
# p9(a27, a50).
# p1(a10).
# p5(a95).

# %% [markdown]
# The following code prepares an existing knowledge base (KB) for use. To use a KB of your choosing, replace countries_kb.txt with the file name of any KB you want to use.
#
# Creates the file:
#
# *   vocab.pkl - Indexes the full set of predicates, constants and variables used by the knowledge base.

# %%
# !python kbencoder.py --kb_path countries_kb.txt --vocab_from_kb --save_vocab
# Out:
# Creating vocabulary from last countries_kb.txt knowledge base

# %% [markdown]
# Train a neural net to convert first-order logic atoms into meaningful numeric vectors. We call these vectors "embeddings," and the learned model the embedding model. The code creates random atoms and then uses a mechanism known as triplet loss to place unifying atoms closer together.
#
# Creates the files:
#
# *   rKB_model.pth - Saves the learned weights for the embedding model
# *   training_loss-45-106-2-50.png - A plot of the training loss after each epoch. This file's name depends on the vocabulary of your KB: the four numbers are number of predicates, number of constants, max arity of the predicates, and the embedding size used. If you changed the KB, you'll need to look up the name in your drive and update the code block that displays this file.

# %%
# !python kbencoder.py --kb_path countries_kb.txt --train_unification_model
# Out:
# Using cuda device
# Uni model embed size: 50
#  [████████████████████] 3500/3500 Anchors generated
#  [████████████████████] 70000/70000 Triplets generated
#  [████████████████████] 70000/70000 Triplet encodings
# Early stopping triggered-------------] 14.8% Epoch | [Epoch 75/500, Training Loss: 0.0239, Validation Loss: 0.4510]
# Saved model.
# Saved plot.
# unification model generated

# %%
img = plt.imread('training_loss-36-759-3-50.png')
plt. imshow(img)

# %% [markdown]
# Generate a set of train and test queries from your knowledge base. This will also generate the deductive closure (all facts that can be inferred) of your KB using forward-chaining.
#
# Produces the files:
#
# *  all_facts.txt - A list of all facts that can be inferred from the KB. This is used to generate queries that are guaranteed to have an answer.
# *  train_queries.txt - A set of training queries where each will have at least one answer.
# *  test_queries.txt - A set of test queries where each will have at least one answer.

# %%
# !python kbencoder.py --kb_path countries_kb.txt -g
# Out:
# Generating facts list...
# Forward chaining depth: 1
# New facts: 17818
# Forward chaining depth: 2
# New facts: 2254
# Forward chaining depth: 3
# New facts: 3870
# Forward chaining depth: 4
# New facts: 5176
# Forward chaining depth: 5
#
# Facts list generated
# 29118 total facts. Max depth = 4
#
# Number of queries: 200
# 100 training queries generated
# 100 testing queries generated

# %% [markdown]
# Create a training set for the scoring model. The examples will consist of goal, rule, score pairs, where a score of 1 means the rule can solve the goal, and 0 means it cannot. It runs the full set of training queries with a randomized backward-chaining process. This step can sometimes take a long time and is not able to take advantage of a GPU (with the countries_kb KB it took ~45 minutes).
#
# Creates a file:
# *  mr_train_examples.csv - Contains a line for each goal/rule/score example.

# %%
# !python kbencoder.py --kb_path countries_kb.txt -p
# Out:
# running training queries...
# Negative facts will be generated
# 1: [threeBorderTrip(C, W)]
# min depth: 8
# Nodes: 29926
# Answers: 1000
#
# 2: [sharesLanguage(Country, C)]
# min depth: 3
# Nodes: 1052
# Answers: 1000
#
# 3: [sharesLanguage(Region, Neighbor)]
# min depth: 3
# Nodes: 1056
# Answers: 1000
#
# 4: [usesSameCurrency(City, C), sameRegion(C, germany), locatedIn(C, europe), sameAlliance(germany, City)]
# min depth: 3
# Nodes: 1161
# Answers: 1000
#
# 5: [cityIn(C, croatia), cityInRegion(C, europe)]
# min depth: 1
# Nodes: 3
# Answers: 2
#
# 6: [officialLanguage(C, english), sharesLanguage(lesotho, C)]
# min depth: 1
# Nodes: 60
# Answers: 59
#
# 7: [currencyOf(City, C), sharesLanguage(City, burundi)]
# min depth: 1
# Nodes: 196
# Answers: 195
#
# 8: [sharesLanguage(Neighbor, Country)]
# min depth: 3
# Nodes: 1069
# Answers: 1000
#
# 9: [threeBorderTrip(L, Z)]
# min depth: 8
# Nodes: 39815
# Answers: 1000
#
# 10: [cityInContinent(City, C), cityInAllianceAndRegion(Continent, g20, C), capitalCity(City), cityInAllianceAndRegion(Continent, brics, C), locatedIn(laos, C)]
# min depth: 3
# Nodes: 628
# Answers: 313
#
# 11: [sameRegion(Country, W)]
# min depth: 3
# Nodes: 1028
# Answers: 1000
#
# 12: [cityInRegion(C, City), cityIn(C, namibia), cityInContinent(C, City), cityInRegion(praia, City)]
# min depth: 3
# Nodes: 628
# Answers: 313
#
# 13: [sameRegion(X, O)]
# min depth: 3
# Nodes: 1030
# Answers: 1000
#
# 14: [usesSameCurrency(vatican_city, C), usesSameCurrency(C, estonia)]
# min depth: 3
# Nodes: 223
# Answers: 26
#
# 15: [cityInContinent(C, City), cityInAlliance(C, g20), cityInContinent(chiang_mai, City)]
# min depth: 3
# Nodes: 628
# Answers: 313
#
# 16: [sameAlliance(Region, Neighbor)]
# min depth: 3
# Nodes: 1056
# Answers: 1000
#
# 17: [sameRegion(C, Z)]
# min depth: 3
# Nodes: 1032
# Answers: 1000
#
# 18: [capitalInContinent(O, Y)]
# min depth: 3
# Nodes: 392
# Answers: 195
#
# 19: [threeBorderTrip(Org, W)]
# min depth: 8
# Nodes: 1701
# Answers: 1000
#
# 20: [twoBorderTrip(City, C), threeBorderTrip(C, germany), countryInAllianceAndRegion(City, cis, europe), sameRegion(City, hungary)]
# min depth: 5
# Nodes: 1617
# Answers: 1000
#
# 21: [threeBorderTrip(C, V)]
# min depth: 8
# Nodes: 29967
# Answers: 1000
#
# 22: [sameAlliance(X, W)]
# min depth: 3
# Nodes: 1052
# Answers: 1000
#
# 23: [currencyOf(City, C), sameRegion(City, City)]
# min depth: 1
# Nodes: 196
# Answers: 195
#
# 24: [officialLanguage(C, ukrainian), twoBorderTrip(C, slovakia)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 25: [sameRegion(W, City)]
# min depth: 3
# Nodes: 1024
# Answers: 1000
#
# 26: [threeBorderTrip(Continent, Region)]
# min depth: 8
# Nodes: 29904
# Answers: 1000
#
# 27: [sameRegion(City, Org)]
# min depth: 3
# Nodes: 1028
# Answers: 1000
#
# 28: [cityIn(C, kenya), cityInRegion(C, africa)]
# min depth: 1
# Nodes: 3
# Answers: 2
#
# 29: [sameRegion(C, City), threeBorderTrip(C, angola), sharesLanguage(City, france), sameRegion(C, nigeria), sameRegion(C, botswana)]
# min depth: 3
# Nodes: 1032
# Answers: 1000
#
# 30: [threeBorderTrip(Country, W)]
# min depth: 8
# Nodes: 32655
# Answers: 1000
#
# 31: [sameRegion(Z, C)]
# min depth: 3
# Nodes: 1033
# Answers: 1000
#
# 32: [sharesLanguage(City, Country)]
# min depth: 3
# Nodes: 1059
# Answers: 1000
#
# 33: [fourBorderTrip(W, Neighbor)]
# Nodes: 1712
# Answers: 1000
#
# 34: [cityInRegion(mashhad, C), cityInRegion(basra, C)]
# min depth: 3
# Nodes: 4
# Answers: 1
#
# 35: [sharesLanguage(Neighbor, C)]
# min depth: 3
# Nodes: 1066
# Answers: 1000
#
# 36: [twoBorderTrip(V, Org)]
# min depth: 5
# Nodes: 1630
# Answers: 1000
#
# 37: [sameRegion(Z, City)]
# min depth: 3
# Nodes: 1030
# Answers: 1000
#
# 38: [officialLanguage(C, uzbek), sameRegion(C, maldives), sameRegion(City, C), sharesLanguage(gambia, City)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 39: [officialLanguage(City, C), fourBorderTrip(libya, City), twoBorderTrip(guinea, City)]
# min depth: 1
# Nodes: 266
# Answers: 265
#
# 40: [fourBorderTrip(L, Country)]
# Nodes: 63690
# Answers: 1000
#
# 41: [cityIn(C, laos), cityInRegion(C, City), locatedIn(afghanistan, City), capitalInAllianceAndRegion(seoul, g20, City)]
# min depth: 1
# Nodes: 3
# Answers: 2
#
# 42: [sharesLanguage(V, Y)]
# min depth: 3
# Nodes: 1043
# Answers: 1000
#
# 43: [fourBorderTrip(R, Continent)]
# Nodes: 53505
# Answers: 1000
#
# 44: [currencyOf(C, belize_dollar), sharesLanguage(C, pakistan), sameRegion(honduras, C)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 45: [currencyOf(C, Continent), threeBorderTrip(C, City), twoBorderTrip(kuwait, City), sameRegion(iran, C)]
# min depth: 1
# Nodes: 196
# Answers: 195
#
# 46: [capitalOf(C, amsterdam), sameRegion(georgia, C)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 47: [currencyOf(C, south_sudanese_pound), sharesLanguage(cameroon, C), sharesLanguage(zimbabwe, C), sharesLanguage(C, botswana), sharesLanguage(C, malta)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 48: [sameAlliance(Org, Org)]
# min depth: 3
# Nodes: 212
# Answers: 105
#
# 49: [twoBorderTrip(W, Neighbor)]
# min depth: 5
# Nodes: 1566
# Answers: 1000
#
# 50: [cityInAllianceAndRegion(W, V, Z)]
# min depth: 4
# Nodes: 391
# Answers: 179
#
# 51: [cityInRegion(C, africa), cityIn(C, egypt)]
# min depth: 3
# Nodes: 128
# Answers: 73
#
# 52: [sharesBorder(C, colombia), sameRegion(C, argentina)]
# min depth: 2
# Nodes: 8
# Answers: 5
#
# 53: [threeBorderTrip(Country, O)]
# min depth: 8
# Nodes: 29940
# Answers: 1000
#
# 54: [sharesLanguage(W, Z)]
# min depth: 3
# Nodes: 1047
# Answers: 1000
#
# 55: [sharesLanguage(france, C), sameRegion(serbia, C)]
# min depth: 3
# Nodes: 291
# Answers: 24
#
# 56: [cityIn(C, belgium), cityInRegion(C, europe)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 57: [cityInRegion(maribor, C), cityInAllianceAndRegion(paris, City, C), cityInAllianceAndRegion(ljubljana, City, C)]
# min depth: 3
# Nodes: 198
# Answers: 1
#
# 58: [sameRegion(W, City)]
# min depth: 3
# Nodes: 1034
# Answers: 1000
#
# 59: [sharesBorder(X, R)]
# min depth: 2
# Nodes: 595
# Answers: 592
#
# 60: [capitalCity(C), capitalOf(cape_verde, C)]
# min depth: 2
# Nodes: 197
# Answers: 195
#
# 61: [cityInRegion(dili, C), cityInContinent(City, C), capitalInContinent(City, C), cityInRegion(chittagong, C), capitalInAllianceAndRegion(new_delhi, brics, C)]
# min depth: 3
# Nodes: 198
# Answers: 1
#
# 62: [cityInRegion(C, City), cityIn(C, sri_lanka), cityInContinent(C, City), countryInAllianceAndRegion(china, Continent, City), cityInAlliance(dublin, Continent)]
# min depth: 3
# Nodes: 628
# Answers: 313
#
# 63: [sharesLanguage(C, tonga), sharesLanguage(C, City), threeBorderTrip(City, Continent), sharesLanguage(Continent, south_sudan), sameRegion(dr_congo, City)]
# min depth: 3
# Nodes: 124
# Answers: 119
#
# 64: [fourBorderTrip(Continent, R)]
# Nodes: 1730
# Answers: 1000
#
# 65: [cityIn(tbilisi, C), threeBorderTrip(City, C), fourBorderTrip(palestine, City), fourBorderTrip(C, switzerland)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 66: [cityInContinent(C, north_america), capitalCity(C), capitalInContinent(C, north_america), cityInRegion(C, north_america), capitalOf(belize, C)]
# min depth: 3
# Nodes: 60
# Answers: 35
#
# 67: [cityInContinent(C, City), cityInRegion(C, City), cityInRegion(Continent, City), cityIn(Continent, benin)]
# min depth: 3
# Nodes: 510
# Answers: 313
#
# 68: [fourBorderTrip(Country, Org)]
# Nodes: 36286
# Answers: 1000
#
# 69: [fourBorderTrip(W, R)]
# Nodes: 3548
# Answers: 1000
#
# 70: [cityIn(C, cambodia), cityInContinent(C, City), cityInRegion(C, City), capitalInContinent(seoul, City)]
# min depth: 1
# Nodes: 3
# Answers: 2
#
# 71: [sameRegion(R, Org)]
# min depth: 3
# Nodes: 1030
# Answers: 1000
#
# 72: [sharesLanguage(C, Org)]
# min depth: 3
# Nodes: 1058
# Answers: 1000
#
# 73: [sharesLanguage(W, L)]
# min depth: 3
# Nodes: 1055
# Answers: 1000
#
# 74: [sameAlliance(Z, Region)]
# min depth: 3
# Nodes: 1051
# Answers: 1000
#
# 75: [twoBorderTrip(V, O)]
# min depth: 5
# Nodes: 1558
# Answers: 1000
#
# 76: [capitalCity(C), cityInAlliance(C, City), cityInAllianceAndRegion(C, City, Continent), twoStepBorderNeighborAlliance(qatar, City), cityInRegion(mashhad, Continent)]
# min depth: 2
# Nodes: 197
# Answers: 195
#
# 77: [currencyOf(new_zealand, C)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 78: [capitalInAlliance(Country, Z)]
# min depth: 3
# Nodes: 212
# Answers: 105
#
# 79: [sharesBorder(W, Continent)]
# min depth: 2
# Nodes: 595
# Answers: 592
#
# 80: [fourBorderTrip(Region, City)]
# Nodes: 100436
# Answers: 683
#
# 81: [fourBorderTrip(Region, X)]
# Nodes: 26071
# Answers: 1000
#
# 82: [sameAlliance(Org, Z)]
# min depth: 3
# Nodes: 1053
# Answers: 1000
#
# 83: [fourBorderTrip(C, L)]
# Nodes: 28025
# Answers: 1000
#
# 84: [sameRegion(V, Region)]
# min depth: 3
# Nodes: 1032
# Answers: 1000
#
# 85: [sharesLanguage(R, Neighbor)]
# min depth: 3
# Nodes: 1037
# Answers: 1000
#
# 86: [cityInRegion(R, Neighbor)]
# min depth: 3
# Nodes: 628
# Answers: 313
#
# 87: [cityInAlliance(C, aukus), cityIn(C, australia)]
# min depth: 3
# Nodes: 320
# Answers: 5
#
# 88: [capitalCity(C), cityIn(C, City), sharesBorder(chad, City)]
# min depth: 2
# Nodes: 197
# Answers: 195
#
# 89: [threeBorderTrip(Country, Org)]
# min depth: 8
# Nodes: 32123
# Answers: 1000
#
# 90: [capitalInContinent(C, africa), cityIn(C, City), sharesLanguage(Continent, City), sameRegion(Continent, Country), sharesLanguage(Country, fiji)]
# min depth: 3
# Nodes: 250
# Answers: 53
#
# 91: [fourBorderTrip(C, City), sharesBorder(poland, C), fourBorderTrip(turkey, City), sameAlliance(azerbaijan, City), twoBorderTrip(slovenia, C)]
# Nodes: 73386
# Answers: 1000
#
# 92: [fourBorderTrip(C, Z)]
# Nodes: 1921
# Answers: 1000
#
# 93: [sameAlliance(Y, Region)]
# min depth: 3
# Nodes: 1051
# Answers: 1000
#
# 94: [sameRegion(City, Y)]
# min depth: 3
# Nodes: 1033
# Answers: 1000
#
# 95: [sameRegion(Z, Region)]
# min depth: 3
# Nodes: 1031
# Answers: 1000
#
# 96: [usesSameCurrency(Z, O)]
# min depth: 3
# Nodes: 1185
# Answers: 1000
#
# 97: [usesSameCurrency(Continent, L)]
# min depth: 3
# Nodes: 1146
# Answers: 1000
#
# 98: [sharesLanguage(W, W)]
# min depth: 3
# Nodes: 532
# Answers: 265
#
# 99: [currencyOf(C, City), sameRegion(tanzania, C), sharesLanguage(C, chad)]
# min depth: 1
# Nodes: 196
# Answers: 195
#
# 100: [threeBorderTrip(L, O)]
# min depth: 8
# Nodes: 1693
# Answers: 1000
#
# Before removing duplicates: 667682 examples
# After removing duplicates: 52975 examples
# pos len=30014, neg len=30014

# %% [markdown]
# Train the scoring model. This step will usually take several minutes, especially if you are not using a GPU (for the countries_kb KB, it takes about 30 minutes on CPU).
#
# Creates a file:
# * uni_mr_model.pt - Contains the weights for the learned scoring model

# %%
# !python nnreasoner.py --embed_type unification
# Out:
# States from vocab: vocab
# Num predicates: 36
# Max arity: 3
# Num constants: 759
# Num variables: 15
#
# Training unification
# Embed size: 50
# Reading examples from mr_train_examples.csv
# Parsing examples...
# Generating embeddings...
# Embedding input size: 2358
#  [███████████████] 60027/60027 Prepping examples
# Loaded data...
# Using cuda device
# /opt/tljh/user/envs/cse327python311/lib/python3.11/site-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# 0	0.22929 (-)
# 50	0.18695 (-0.0005)
# 100	0.18261 (-0.0002)
# 150	0.18059 (-0.0002)
# 200	0.17891 (-0.0001)
# 250	0.17765 (-0.0001)
# 300	0.17577 (-0.0001)
# 350	0.17455 (-0.0001)
# 400	0.17280 (-0.0001)
# 450	0.17107 (-9.3931)
# 500	0.16859 (-8.9619)
# 550	0.16774 (-8.4064)
# 600	0.16594 (-7.9637)
# 650	0.16558 (-7.4662)
# 700	0.16556 (-7.3314)
# 749	0.16375 (-5.7173)
# Saved training loss figure.

# %%
img = plt.imread('guided_loss-unification36-759-3-50.png')
plt. imshow(img)

# %% [markdown]
# Evaluate the scoring model by running evaluate.py. We compare the standard backward-chaining algorithm (-s) with the one that uses our learned scoring model (-u).
#
# The output lists each query, and then provides a line that gives information about query execution. These are: number of nodes explored in the tree, depth of the solution, execution time in seconds, and the speed of exploring the tree (nodes per second).
#
# The names of the files produced depend on the KB used and the options selected. The code below produces the files:
#
# * std-45-106-2-50.csv - A CSV file with query results for the standard backward-chaining algorithm
# * ming-45-106-2-50.csv - A CSV file with query results for the learned reasoner. ming stands for "min scoring goal" and is the default strategy for deciding how to make use of the scores
#
# If you use a different knowledge base, you will likely get different file names that depend on the features of that KB's vocabulary.

# %%
# !python evaluate.py --kb countries_kb.txt -s
# !python evaluate.py --kb countries_kb.txt -u
# Out:
# using cuda device
# STANDARD
#
# Query 1: [sameRegion(City, Country)]
# 4 :: 3 - 00:00:00 (1168 nps)
#
# Query 2: [sameRegion(Neighbor, C)]
# 4 :: 3 - 00:00:00 (1211 nps)
#
# Query 3: [threeBorderTrip(ukraine, C), sameRegion(myanmar, C)]
# 124 :: 11 - 00:00:00 (747 nps)
#
# Query 4: [currencyOf(City, C), currencyOf(israel, C), sameRegion(turkey, City), sameRegion(City, iraq)]
# 58 :: 8 - 00:00:00 (1804 nps)
#
# Query 5: [sharesLanguage(Country, Region)]
# 4 :: 3 - 00:00:00 (617 nps)
#
# Query 6: [sharesLanguage(V, Neighbor)]
# 4 :: 3 - 00:00:00 (980 nps)
#
# Query 7: [sharesLanguage(Y, Z)]
# 4 :: 3 - 00:00:00 (930 nps)
#
# Query 8: [fourBorderTrip(Neighbor, O)]
# 13 :: 11 - 00:00:00 (1201 nps)
#
# Query 9: [sharesLanguage(Y, Z)]
# 4 :: 3 - 00:00:00 (54171 nps)
#
# Query 10: [sharesLanguage(Country, R)]
# 4 :: 3 - 00:00:00 (2480 nps)
#
# Query 11: [officialLanguage(City, C), threeBorderTrip(City, india), fourBorderTrip(laos, City)]
# Query failed!!!
# 20259 :: 0 - 00:00:02 (9508 nps)
#
# Query 12: [sharesLanguage(Y, V)]
# 4 :: 3 - 00:00:00 (2265 nps)
#
# Query 13: [sameRegion(City, Z)]
# 4 :: 3 - 00:00:00 (725 nps)
#
# Query 14: [sameRegion(C, malta), sameRegion(C, City), sameRegion(united_kingdom, City)]
# 10 :: 9 - 00:00:00 (1107 nps)
#
# Query 15: [threeBorderTrip(R, Country)]
# 10 :: 8 - 00:00:00 (1116 nps)
#
# Query 16: [fourBorderTrip(monaco, C), threeBorderTrip(City, C), sameRegion(belarus, City)]
# Query failed!!!
# 94452 :: 0 - 00:00:01 (48080 nps)
#
# Query 17: [currencyOf(C, swissFranc), sameRegion(norway, C)]
# 5 :: 4 - 00:00:00 (1210 nps)
#
# Query 18: [fourBorderTrip(City, Continent)]
# 13 :: 11 - 00:00:00 (1624 nps)
#
# Query 19: [fourBorderTrip(City, Region)]
# 13 :: 11 - 00:00:00 (4829 nps)
#
# Query 20: [sameRegion(X, W)]
# 4 :: 3 - 00:00:00 (1169 nps)
#
# Query 21: [fourBorderTrip(C, vatican_city), sameRegion(estonia, C), fourBorderTrip(denmark, C)]
# Query failed!!!
# 56742 :: 0 - 00:00:01 (33651 nps)
#
# Query 22: [fourBorderTrip(W, O)]
# 13 :: 11 - 00:00:00 (3720 nps)
#
# Query 23: [twoBorderTrip(Continent, City)]
# 6 :: 5 - 00:00:00 (1152 nps)
#
# Query 24: [twoStepBorderNeighborAlliance(azerbaijan, C), cityInAllianceAndRegion(astana, C, asia)]
# 12 :: 11 - 00:00:00 (1145 nps)
#
# Query 25: [fourBorderTrip(X, Region)]
# 13 :: 11 - 00:00:00 (3775 nps)
#
# Query 26: [sameRegion(City, C), sharesLanguage(C, india), sharesLanguage(india, C), sharesLanguage(City, united_states)]
# 1335 :: 12 - 00:00:00 (5597 nps)
#
# Query 27: [sharesLanguage(C, Neighbor)]
# 4 :: 3 - 00:00:00 (295 nps)
#
# Query 28: [cityInAlliance(C, g20), cityInRegion(C, City), cityInAllianceAndRegion(moscow, Continent, City), cityInAlliance(almaty, Continent)]
# 14 :: 13 - 00:00:00 (916 nps)
#
# Query 29: [sameRegion(Neighbor, X)]
# 4 :: 3 - 00:00:00 (1664 nps)
#
# Query 30: [threeBorderTrip(City, V)]
# 10 :: 8 - 00:00:00 (1363 nps)
#
# Query 31: [sharesBorder(L, Region)]
# 3 :: 2 - 00:00:00 (912 nps)
#
# Query 32: [sharesLanguage(City, V)]
# 4 :: 3 - 00:00:00 (1447 nps)
#
# Query 33: [capitalInAllianceAndRegion(london, C, europe), cityInAllianceAndRegion(canberra, C, oceania)]
# 13 :: 8 - 00:00:00 (1644 nps)
#
# Query 34: [sharesLanguage(Y, Org)]
# 4 :: 3 - 00:00:00 (2007 nps)
#
# Query 35: [sharesLanguage(Z, Org)]
# 4 :: 3 - 00:00:00 (453 nps)
#
# Query 36: [sameRegion(Country, Region)]
# 4 :: 3 - 00:00:00 (1201 nps)
#
# Query 37: [twoBorderTrip(Neighbor, Continent)]
# 6 :: 5 - 00:00:00 (1131 nps)
#
# Query 38: [officialLanguage(City, C), sharesLanguage(Continent, City), threeBorderTrip(Continent, libya), sameRegion(lesotho, Continent)]
# 496 :: 15 - 00:00:00 (1394 nps)
#
# Query 39: [sameAlliance(Z, L)]
# 4 :: 3 - 00:00:00 (902 nps)
#
# Query 40: [sameRegion(City, Neighbor)]
# 4 :: 3 - 00:00:00 (2714 nps)
#
# Query 41: [twoBorderTrip(C, X)]
# 6 :: 5 - 00:00:00 (1117 nps)
#
# Query 42: [currencyOf(C, City), threeBorderTrip(china, C)]
# 678 :: 9 - 00:00:00 (1270 nps)
#
# Query 43: [fourBorderTrip(City, Z)]
# 13 :: 11 - 00:00:00 (1487 nps)
#
# Query 44: [threeBorderTrip(Country, Continent)]
# 10 :: 8 - 00:00:00 (622 nps)
#
# Query 45: [cityInRegion(thies, C), locatedIn(tunisia, C)]
# 5 :: 4 - 00:00:00 (978 nps)
#
# Query 46: [sameRegion(R, Continent)]
# 4 :: 3 - 00:00:00 (998 nps)
#
# Query 47: [sharesLanguage(V, O)]
# 4 :: 3 - 00:00:00 (2265 nps)
#
# Query 48: [eurozoneCity(C), cityInAllianceAndRegion(C, nato, europe)]
# 9 :: 8 - 00:00:00 (1632 nps)
#
# Query 49: [officialLanguage(C, tamil), sameRegion(C, vietnam)]
# 5 :: 4 - 00:00:00 (1137 nps)
#
# Query 50: [fourBorderTrip(City, Neighbor)]
# 13 :: 11 - 00:00:00 (5275 nps)
#
# Query 51: [sameRegion(Country, Org)]
# 4 :: 3 - 00:00:00 (1394 nps)
#
# Query 52: [sameRegion(saint_vincent_and_the_grenadines, C), twoStepBorderNeighborAlliance(C, City), capitalInAlliance(washington_dc, City), sameRegion(C, el_salvador), sharesLanguage(C, jamaica)]
# Query failed!!!
# 498 :: 0 - 00:00:00 (2474 nps)
#
# Query 53: [currencyOf(uruguay, C)]
# 2 :: 1 - 00:00:00 (1222 nps)
#
# Query 54: [officialLanguage(C, dutch), fourBorderTrip(kazakhstan, C)]
# 395 :: 12 - 00:00:00 (2137 nps)
#
# Query 55: [twoStepBorderNeighborAlliance(R, X)]
# 8 :: 7 - 00:00:00 (1015 nps)
#
# Query 56: [sharesLanguage(O, Continent)]
# 4 :: 3 - 00:00:00 (859 nps)
#
# Query 57: [twoBorderTrip(Continent, Y)]
# 6 :: 5 - 00:00:00 (2479 nps)
#
# Query 58: [cityIn(C, nigeria), capitalInContinent(C, City), cityInContinent(gaborone, City)]
# 8 :: 7 - 00:00:00 (937 nps)
#
# Query 59: [threeBorderTrip(Continent, Region)]
# 10 :: 8 - 00:00:00 (1223 nps)
#
# Query 60: [twoStepBorderNeighborAlliance(R, L)]
# 8 :: 7 - 00:00:00 (8443 nps)
#
# Query 61: [cityInContinent(C, City), cityInRegion(C, City), cityIn(C, cambodia), countryInAllianceAndRegion(Continent, g20, City), sameAlliance(pakistan, Continent)]
# 797 :: 13 - 00:00:01 (794 nps)
#
# Query 62: [sharesLanguage(W, Neighbor)]
# 4 :: 3 - 00:00:00 (753 nps)
#
# Query 63: [sharesLanguage(C, philippines), sharesLanguage(sierra_leone, C)]
# 17 :: 6 - 00:00:00 (1144 nps)
#
# Query 64: [twoStepBorderNeighborAlliance(C, W)]
# 8 :: 7 - 00:00:00 (1436 nps)
#
# Query 65: [capitalInContinent(sanaa, C), cityInContinent(baghdad, C), cityInRegion(ramallah, C), capitalInContinent(ankara, C)]
# 13 :: 12 - 00:00:00 (991 nps)
#
# Query 66: [currencyOf(C, rand), sameRegion(C, C)]
# 5 :: 4 - 00:00:00 (1249 nps)
#
# Query 67: [currencyOf(C, City), sameRegion(C, Continent), sharesLanguage(Continent, eswatini)]
# 32 :: 7 - 00:00:00 (951 nps)
#
# Query 68: [sameRegion(R, Y)]
# 4 :: 3 - 00:00:00 (2773 nps)
#
# Query 69: [sameRegion(O, Country)]
# 4 :: 3 - 00:00:00 (288 nps)
#
# Query 70: [cityInContinent(kosice, C), cityInContinent(City, C), capitalInAllianceAndRegion(City, eu, C)]
# 11 :: 10 - 00:00:00 (1075 nps)
#
# Query 71: [sharesLanguage(C, City), threeBorderTrip(C, Country), sharesBorder(City, Continent), threeBorderTrip(egypt, Continent), twoBorderTrip(Country, C)]
# Query failed!!!
# 1000000 :: 0 - 00:00:14 (70461 nps)
#
# Query 72: [sameRegion(Org, X)]
# 4 :: 3 - 00:00:00 (212 nps)
#
# Query 73: [sharesLanguage(X, L)]
# 4 :: 3 - 00:00:00 (901 nps)
#
# Query 74: [fourBorderTrip(Z, City)]
# 13 :: 11 - 00:00:00 (2272 nps)
#
# Query 75: [capitalOf(C, City), sharesLanguage(senegal, C), cityIn(City, C), capitalInContinent(City, africa), fourBorderTrip(palestine, C)]
# Query failed!!!
# 1118 :: 0 - 00:00:00 (2030 nps)
#
# Query 76: [sameRegion(R, V)]
# 4 :: 3 - 00:00:00 (2503 nps)
#
# Query 77: [threeBorderTrip(Country, Org)]
# 10 :: 8 - 00:00:00 (2290 nps)
#
# Query 78: [officialLanguage(C, Continent), sameRegion(City, C), sameRegion(czechia, City)]
# 8 :: 7 - 00:00:00 (772 nps)
#
# Query 79: [eurozoneCity(C), cityInAllianceAndRegion(C, Continent, City), cityInAllianceAndRegion(dublin, Continent, City), twoStepBorderNeighborAlliance(north_macedonia, Continent), cityInRegion(zurich, City)]
# Query failed!!!
# 1144 :: 0 - 00:00:00 (2544 nps)
#
# Query 80: [threeBorderTrip(Country, Region)]
# 10 :: 8 - 00:00:00 (47118 nps)
#
# Query 81: [fourBorderTrip(V, Y)]
# 13 :: 11 - 00:00:00 (617 nps)
#
# Query 82: [capitalInContinent(london, C), cityInRegion(City, C), cityIn(City, slovenia)]
# 96 :: 7 - 00:00:00 (1028 nps)
#
# Query 83: [twoBorderTrip(Z, Z)]
# 7 :: 5 - 00:00:00 (629 nps)
#
# Query 84: [sharesLanguage(C, C), sameRegion(C, City), fourBorderTrip(City, Continent), threeBorderTrip(Continent, romania), sameRegion(C, thailand)]
# Query failed!!!
# 1000000 :: 0 - 00:00:18 (53937 nps)
#
# Query 85: [cityInRegion(yerevan, C), countryInAllianceAndRegion(netherlands, nato, C)]
# 7 :: 6 - 00:00:00 (1264 nps)
#
# Query 86: [sharesLanguage(namibia, C), threeBorderTrip(C, panama), sharesLanguage(City, C), sharesLanguage(City, cameroon)]
# Query failed!!!
# 3099 :: 0 - 00:00:00 (3181 nps)
#
# Query 87: [cityInRegion(C, City), eurozoneCity(C), cityInAllianceAndRegion(split, eu, City), locatedIn(bulgaria, City), countryInAllianceAndRegion(belgium, nato, City)]
# 16 :: 15 - 00:00:00 (1712 nps)
#
# Query 88: [currencyOf(C, turkmen_manat), fourBorderTrip(moldova, C), sameRegion(laos, C)]
# 125 :: 15 - 00:00:00 (1223 nps)
#
# Query 89: [usesSameCurrency(Z, V)]
# 4 :: 3 - 00:00:00 (182 nps)
#
# Query 90: [sameRegion(Neighbor, Neighbor)]
# 4 :: 3 - 00:00:00 (2602 nps)
#
# Query 91: [cityInAllianceAndRegion(abu_dhabi, brics, C), locatedIn(lebanon, C)]
# 6 :: 5 - 00:00:00 (968 nps)
#
# Query 92: [officialLanguage(C, kirundi), threeBorderTrip(City, C), threeBorderTrip(tanzania, City)]
# Query failed!!!
# 18617 :: 0 - 00:00:01 (16270 nps)
#
# Query 93: [fourBorderTrip(yemen, C), twoBorderTrip(C, syria), fourBorderTrip(C, somalia)]
# Query failed!!!
# 2126 :: 0 - 00:00:00 (6687 nps)
#
# Query 94: [capitalInContinent(City, V)]
# 4 :: 3 - 00:00:00 (171 nps)
#
# Query 95: [threeBorderTrip(Z, City)]
# 10 :: 8 - 00:00:00 (346 nps)
#
# Query 96: [cityInContinent(City, C), cityInAllianceAndRegion(warsaw, g20, C), capitalInContinent(City, C), capitalOf(lithuania, City), cityInRegion(City, C)]
# 567 :: 14 - 00:00:00 (2132 nps)
#
# Query 97: [sharesLanguage(Org, C)]
# 4 :: 3 - 00:00:00 (176 nps)
#
# Query 98: [fourBorderTrip(Neighbor, C)]
# 13 :: 11 - 00:00:00 (2191 nps)
#
# Query 99: [sameRegion(City, C), sharesLanguage(C, france), threeBorderTrip(City, south_sudan), fourBorderTrip(C, south_sudan)]
# Query failed!!!
# 132413 :: 0 - 00:00:03 (38618 nps)
#
# Query 100: [fourBorderTrip(O, Continent)]
# 13 :: 11 - 00:00:00 (415 nps)
#
# std: 23357.36 nodes/query
# 12 queries failed
# Time to run all queries: 49.159844911000015
# using cuda device
# UNITY: ming
# 	Embedding Model: rKB_model.pth
# 	Scoring Model: uni_mr_model.pt
#
# 	Control: mingoal
# 	Rule Eval: Max Rule
# Learned Embedding: Network using cuda
# /opt/tljh/user/envs/cse327python311/lib/python3.11/site-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# Query 1: [sameRegion(City, Country)]
# 4 :: 3 - 00:00:01 (3 nps)
#
# Query 2: [sameRegion(Neighbor, C)]
# 4 :: 3 - 00:00:00 (7 nps)
#
# Query 3: [threeBorderTrip(ukraine, C), sameRegion(myanmar, C)]
# 182 :: 11 - 00:00:02 (68 nps)
#
# Query 4: [currencyOf(City, C), currencyOf(israel, C), sameRegion(turkey, City), sameRegion(City, iraq)]
# 116 :: 8 - 00:00:01 (63 nps)
#
# Query 5: [sharesLanguage(Country, Region)]
# 4 :: 3 - 00:00:00 (5 nps)
#
# Query 6: [sharesLanguage(V, Neighbor)]
# 4 :: 3 - 00:00:00 (5 nps)
#
# Query 7: [sharesLanguage(Y, Z)]
# 4 :: 3 - 00:00:00 (5 nps)
#
# Query 8: [fourBorderTrip(Neighbor, O)]
# 644 :: 11 - 00:00:03 (202 nps)
#
# Query 9: [sharesLanguage(Y, Z)]
# 4 :: 3 - 00:00:00 (13599 nps)
#
# Query 10: [sharesLanguage(Country, R)]
# 4 :: 3 - 00:00:00 (7 nps)
#
# Query 11: [officialLanguage(City, C), threeBorderTrip(City, india), fourBorderTrip(laos, City)]
# Query failed!!!
# 1000000 :: 0 - 00:00:54 (18477 nps)
#
# Query 12: [sharesLanguage(Y, V)]
# 4 :: 3 - 00:00:00 (257 nps)
#
# Query 13: [sameRegion(City, Z)]
# 4 :: 3 - 00:00:00 (14 nps)
#
# Query 14: [sameRegion(C, malta), sameRegion(C, City), sameRegion(united_kingdom, City)]
# 3138 :: 8 - 00:00:04 (764 nps)
#
# Query 15: [threeBorderTrip(R, Country)]
# 608 :: 8 - 00:00:01 (392 nps)
#
# Query 16: [fourBorderTrip(monaco, C), threeBorderTrip(City, C), sameRegion(belarus, City)]
# Query failed!!!
# 1000000 :: 0 - 00:01:31 (10896 nps)
#
# Query 17: [currencyOf(C, swissFranc), sameRegion(norway, C)]
# 5 :: 4 - 00:00:00 (14 nps)
#
# Query 18: [fourBorderTrip(City, Continent)]
# 644 :: 11 - 00:00:03 (197 nps)
#
# Query 19: [fourBorderTrip(City, Region)]
# 644 :: 11 - 00:00:01 (529 nps)
#
# Query 20: [sameRegion(X, W)]
# 4 :: 3 - 00:00:00 (7 nps)
#
# Query 21: [fourBorderTrip(C, vatican_city), sameRegion(estonia, C), fourBorderTrip(denmark, C)]
# Query failed!!!
# 1000000 :: 0 - 00:01:05 (15198 nps)
#
# Query 22: [fourBorderTrip(W, O)]
# 644 :: 11 - 00:00:02 (246 nps)
#
# Query 23: [twoBorderTrip(Continent, City)]
# 6 :: 5 - 00:00:01 (4 nps)
#
# Query 24: [twoStepBorderNeighborAlliance(azerbaijan, C), cityInAllianceAndRegion(astana, C, asia)]
# 46 :: 11 - 00:00:00 (123 nps)
#
# Query 25: [fourBorderTrip(X, Region)]
# 644 :: 11 - 00:00:01 (469 nps)
#
# Query 26: [sameRegion(City, C), sharesLanguage(C, india), sharesLanguage(india, C), sharesLanguage(City, united_states)]
# 13 :: 12 - 00:00:00 (33 nps)
#
# Query 27: [sharesLanguage(C, Neighbor)]
# 4 :: 3 - 00:00:00 (5 nps)
#
# Query 28: [cityInAlliance(C, g20), cityInRegion(C, City), cityInAllianceAndRegion(moscow, Continent, City), cityInAlliance(almaty, Continent)]
# 3206 :: 13 - 00:00:06 (519 nps)
#
# Query 29: [sameRegion(Neighbor, X)]
# 4 :: 3 - 00:00:00 (6 nps)
#
# Query 30: [threeBorderTrip(City, V)]
# 614 :: 8 - 00:00:01 (386 nps)
#
# Query 31: [sharesBorder(L, Region)]
# 3 :: 2 - 00:00:00 (7 nps)
#
# Query 32: [sharesLanguage(City, V)]
# 4 :: 3 - 00:00:00 (5 nps)
#
# Query 33: [capitalInAllianceAndRegion(london, C, europe), cityInAllianceAndRegion(canberra, C, oceania)]
# 9 :: 8 - 00:00:00 (75 nps)
#
# Query 34: [sharesLanguage(Y, Org)]
# 4 :: 3 - 00:00:00 (5 nps)
#
# Query 35: [sharesLanguage(Z, Org)]
# 4 :: 3 - 00:00:00 (6 nps)
#
# Query 36: [sameRegion(Country, Region)]
# 4 :: 3 - 00:00:00 (6 nps)
#
# Query 37: [twoBorderTrip(Neighbor, Continent)]
# 6 :: 5 - 00:00:01 (4 nps)
#
# Query 38: [officialLanguage(City, C), sharesLanguage(Continent, City), threeBorderTrip(Continent, libya), sameRegion(lesotho, Continent)]
# 13680 :: 15 - 00:00:18 (728 nps)
#
# Query 39: [sameAlliance(Z, L)]
# 4 :: 3 - 00:00:00 (12 nps)
#
# Query 40: [sameRegion(City, Neighbor)]
# 4 :: 3 - 00:00:00 (13 nps)
#
# Query 41: [twoBorderTrip(C, X)]
# 7 :: 5 - 00:00:01 (5 nps)
#
# Query 42: [currencyOf(C, City), threeBorderTrip(china, C)]
# 2730 :: 9 - 00:00:03 (713 nps)
#
# Query 43: [fourBorderTrip(City, Z)]
# 644 :: 11 - 00:00:03 (194 nps)
#
# Query 44: [threeBorderTrip(Country, Continent)]
# 606 :: 8 - 00:00:00 (712 nps)
#
# Query 45: [cityInRegion(thies, C), locatedIn(tunisia, C)]
# 5 :: 4 - 00:00:00 (17 nps)
#
# Query 46: [sameRegion(R, Continent)]
# 4 :: 3 - 00:00:00 (7 nps)
#
# Query 47: [sharesLanguage(V, O)]
# 4 :: 3 - 00:00:00 (10 nps)
#
# Query 48: [eurozoneCity(C), cityInAllianceAndRegion(C, nato, europe)]
# 422 :: 8 - 00:00:02 (206 nps)
#
# Query 49: [officialLanguage(C, tamil), sameRegion(C, vietnam)]
# 5 :: 4 - 00:00:00 (17 nps)
#
# Query 50: [fourBorderTrip(City, Neighbor)]
# 644 :: 11 - 00:00:01 (511 nps)
#
# Query 51: [sameRegion(Country, Org)]
# 4 :: 3 - 00:00:00 (13 nps)
#
# Query 52: [sameRegion(saint_vincent_and_the_grenadines, C), twoStepBorderNeighborAlliance(C, City), capitalInAlliance(washington_dc, City), sameRegion(C, el_salvador), sharesLanguage(C, jamaica)]
# Query failed!!!
# 1000000 :: 0 - 00:01:28 (11287 nps)
#
# Query 53: [currencyOf(uruguay, C)]
# 2 :: 1 - 00:00:00 (459 nps)
#
# Query 54: [officialLanguage(C, dutch), fourBorderTrip(kazakhstan, C)]
# 11669 :: 12 - 00:00:09 (1178 nps)
#
# Query 55: [twoStepBorderNeighborAlliance(R, X)]
# 622 :: 7 - 00:00:01 (441 nps)
#
# Query 56: [sharesLanguage(O, Continent)]
# 4 :: 3 - 00:00:00 (5 nps)
#
# Query 57: [twoBorderTrip(Continent, Y)]
# 6 :: 5 - 00:00:01 (4 nps)
#
# Query 58: [cityIn(C, nigeria), capitalInContinent(C, City), cityInContinent(gaborone, City)]
# 8 :: 7 - 00:00:00 (22 nps)
#
# Query 59: [threeBorderTrip(Continent, Region)]
# 604 :: 8 - 00:00:01 (379 nps)
#
# Query 60: [twoStepBorderNeighborAlliance(R, L)]
# 622 :: 7 - 00:00:00 (4106 nps)
#
# Query 61: [cityInContinent(C, City), cityInRegion(C, City), cityIn(C, cambodia), countryInAllianceAndRegion(Continent, g20, City), sameAlliance(pakistan, Continent)]
# 21 :: 13 - 00:00:01 (16 nps)
#
# Query 62: [sharesLanguage(W, Neighbor)]
# 4 :: 3 - 00:00:00 (5 nps)
#
# Query 63: [sharesLanguage(C, philippines), sharesLanguage(sierra_leone, C)]
# 7 :: 6 - 00:00:00 (15 nps)
#
# Query 64: [twoStepBorderNeighborAlliance(C, W)]
# 322 :: 7 - 00:00:00 (341 nps)
#
# Query 65: [capitalInContinent(sanaa, C), cityInContinent(baghdad, C), cityInRegion(ramallah, C), capitalInContinent(ankara, C)]
# 13 :: 12 - 00:00:00 (32 nps)
#
# Query 66: [currencyOf(C, rand), sameRegion(C, C)]
# 4 :: 3 - 00:00:00 (15 nps)
#
# Query 67: [currencyOf(C, City), sameRegion(C, Continent), sharesLanguage(Continent, eswatini)]
# 8 :: 7 - 00:00:01 (7 nps)
#
# Query 68: [sameRegion(R, Y)]
# 4 :: 3 - 00:00:00 (7 nps)
#
# Query 69: [sameRegion(O, Country)]
# 4 :: 3 - 00:00:00 (7 nps)
#
# Query 70: [cityInContinent(kosice, C), cityInContinent(City, C), capitalInAllianceAndRegion(City, eu, C)]
# 250 :: 10 - 00:00:01 (127 nps)
#
# Query 71: [sharesLanguage(C, City), threeBorderTrip(C, Country), sharesBorder(City, Continent), threeBorderTrip(egypt, Continent), twoBorderTrip(Country, C)]
# Query failed!!!
# 1000000 :: 0 - 00:05:24 (3085 nps)
#
# Query 72: [sameRegion(Org, X)]
# 4 :: 3 - 00:00:00 (6 nps)
#
# Query 73: [sharesLanguage(X, L)]
# 4 :: 3 - 00:00:00 (5 nps)
#
# Query 74: [fourBorderTrip(Z, City)]
# 644 :: 11 - 00:00:03 (195 nps)
#
# Query 75: [capitalOf(C, City), sharesLanguage(senegal, C), cityIn(City, C), capitalInContinent(City, africa), fourBorderTrip(palestine, C)]
# Query failed!!!
# 1000000 :: 0 - 00:00:56 (17705 nps)
#
# Query 76: [sameRegion(R, V)]
# 4 :: 3 - 00:00:00 (6 nps)
#
# Query 77: [threeBorderTrip(Country, Org)]
# 9 :: 8 - 00:00:01 (7 nps)
#
# Query 78: [officialLanguage(C, Continent), sameRegion(City, C), sameRegion(czechia, City)]
# 1012 :: 7 - 00:00:04 (244 nps)
#
# Query 79: [eurozoneCity(C), cityInAllianceAndRegion(C, Continent, City), cityInAllianceAndRegion(dublin, Continent, City), twoStepBorderNeighborAlliance(north_macedonia, Continent), cityInRegion(zurich, City)]
# Query failed!!!
# 722801 :: 0 - 00:01:50 (6556 nps)
#
# Query 80: [threeBorderTrip(Country, Region)]
# 306 :: 8 - 00:00:01 (200 nps)
#
# Query 81: [fourBorderTrip(V, Y)]
# 644 :: 11 - 00:00:03 (192 nps)
#
# Query 82: [capitalInContinent(london, C), cityInRegion(City, C), cityIn(City, slovenia)]
# 8 :: 7 - 00:00:01 (6 nps)
#
# Query 83: [twoBorderTrip(Z, Z)]
# 302 :: 4 - 00:00:02 (148 nps)
#
# Query 84: [sharesLanguage(C, C), sameRegion(C, City), fourBorderTrip(City, Continent), threeBorderTrip(Continent, romania), sameRegion(C, thailand)]
# Query failed!!!
# 1000000 :: 0 - 00:03:03 (5449 nps)
#
# Query 85: [cityInRegion(yerevan, C), countryInAllianceAndRegion(netherlands, nato, C)]
# 7 :: 6 - 00:00:00 (18 nps)
#
# Query 86: [sharesLanguage(namibia, C), threeBorderTrip(C, panama), sharesLanguage(City, C), sharesLanguage(City, cameroon)]
# Query failed!!!
# 343268 :: 0 - 00:01:21 (4202 nps)
#
# Query 87: [cityInRegion(C, City), eurozoneCity(C), cityInAllianceAndRegion(split, eu, City), locatedIn(bulgaria, City), countryInAllianceAndRegion(belgium, nato, City)]
# 1958 :: 15 - 00:00:06 (314 nps)
#
# Query 88: [currencyOf(C, turkmen_manat), fourBorderTrip(moldova, C), sameRegion(laos, C)]
# 336 :: 15 - 00:00:01 (191 nps)
#
# Query 89: [usesSameCurrency(Z, V)]
# 4 :: 3 - 00:00:00 (7 nps)
#
# Query 90: [sameRegion(Neighbor, Neighbor)]
# 3 :: 2 - 00:00:00 (12 nps)
#
# Query 91: [cityInAllianceAndRegion(abu_dhabi, brics, C), locatedIn(lebanon, C)]
# 6 :: 5 - 00:00:00 (98 nps)
#
# Query 92: [officialLanguage(C, kirundi), threeBorderTrip(City, C), threeBorderTrip(tanzania, City)]
# 25008 :: 12 - 00:00:12 (1947 nps)
#
# Query 93: [fourBorderTrip(yemen, C), twoBorderTrip(C, syria), fourBorderTrip(C, somalia)]
# Query failed!!!
# 1000000 :: 0 - 00:02:07 (7867 nps)
#
# Query 94: [capitalInContinent(City, V)]
# 4 :: 3 - 00:00:00 (12 nps)
#
# Query 95: [threeBorderTrip(Z, City)]
# 9 :: 8 - 00:00:00 (12 nps)
#
# Query 96: [cityInContinent(City, C), cityInAllianceAndRegion(warsaw, g20, C), capitalInContinent(City, C), capitalOf(lithuania, City), cityInRegion(City, C)]
# 52 :: 13 - 00:00:01 (50 nps)
#
# Query 97: [sharesLanguage(Org, C)]
# 4 :: 3 - 00:00:00 (9 nps)
#
# Query 98: [fourBorderTrip(Neighbor, C)]
# 644 :: 11 - 00:00:02 (308 nps)
#
# Query 99: [sameRegion(City, C), sharesLanguage(C, france), threeBorderTrip(City, south_sudan), fourBorderTrip(C, south_sudan)]
# Query failed!!!
# 1000000 :: 0 - 00:03:28 (4802 nps)
#
# Query 100: [fourBorderTrip(O, Continent)]
# 644 :: 11 - 00:00:02 (278 nps)
#
# ming: 101418.58 nodes/query
# 11 queries failed
# Time to run all queries: 1539.275633894999

# %% [markdown]
# The results suggest only minor improvements for the countries_kb KB: on average 3.75 vs. 4.39 node per query when I ran it. You may get different results due to the randomization of training and random selection of test queries. Larger, more complex KBs can see much larger improvements, sometimes an order of magnitude or more.
#
# The code below shows the first 10 lines of each query result file. A given line has:
# * query sequence number
# * configuration name
# * number of nodes explored
# * depth of solution (0 if no solution found)
# * did the system find a solution (true/false)
# * time in seconds
#
# You can import these files into a spreadsheet in order to create plots or summary statistics.

# %%
# !head std-36-759-3-50.csv
# !head ming-36-759-3-50.csv
# Out:
# query,std reasoner,std nodes explored,std min depth,success,time
# 1,std,4,3,True,0.003424643000000671
# 2,std,4,3,True,0.003300348999999869
# 3,std,124,11,True,0.1658790640000003
# 4,std,58,8,True,0.03214092899999965
# 5,std,4,3,True,0.006477725000000767
# 6,std,4,3,True,0.004078798000000106
# 7,std,4,3,True,0.004299596000000072
# 8,std,13,11,True,0.010816864999999787
# 9,std,4,3,True,7.383900000057508e-05
# query,ming reasoner,ming nodes explored,ming min depth,success,time
# 1,ming,4,3,True,1.0091014989999998
# 2,ming,4,3,True,0.5428559960000001
# 3,ming,182,11,True,2.648553897000001
# 4,ming,116,8,True,1.8380286680000015
# 5,ming,4,3,True,0.7199036520000011
# 6,ming,4,3,True,0.7312902779999995
# 7,ming,4,3,True,0.7172674309999998
# 8,ming,644,11,True,3.1791401730000004
# 9,ming,4,3,True,0.0002941199999995092
