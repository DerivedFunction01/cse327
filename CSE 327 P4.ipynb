# %% [markdown]
# The block below imports a necessary module and checks if you are in the right directory. If you do not see a list of python files when you run the block, please make sure you have uploaded the zip file and unzipped it.

# %%
import matplotlib.pyplot as plt
# %pwd
# %ls
# Out:
#  atomgenerator.py    embedmodel.py       hw.md                 nnunifier.py
#  autoencoder.py      evaluate.py         kbencoder.py          reasoner.py
#  basictypes.py       fact_generator.py   kbparser.py           termwalk.py
#  chainbased.py       gameofthrones.txt   knowledgebase.py      vocab.py
#  countries_kb.txt    gen_queries.py      mr_back_reasoner.py
# 'CSE 327 P4.ipynb'   helpers/            nnreasoner.py

# %% [markdown]
# If you want to create a random knowledge base, run the following code.
#
# Creates the files:
#
# * randomKB.txt - A random KB generated using 10 predicates and 100 constants.
# * vocab.pkl - Indexes the full set of predicates, constants and variables used by the knowledge base.

# %%
# !python kbencoder.py --generate_kb --new_vocab --save_vocab
# !head randomKB.txt
# Out:
# Classes: 100000000000.0
# Max arity: 5
# KB generated (150)
# p3(a30, a20).
# p1(a0, a84).
# p0(a45, a71).
# p7(a96, a11).
# p5(a5).
# p2(a7, a0, a23).
# p4(a63, a84, a12).
# p6(a72).
# p9(a18, a8, a69).
# p0(a15, a67).

# %% [markdown]
# The following code prepares an existing knowledge base (KB) for use. To use a KB of your choosing, replace countries_kb.txt with the file name of any KB you want to use.
#
# Creates the file:
#
# *   vocab.pkl - Indexes the full set of predicates, constants and variables used by the knowledge base.

# %%
# !python kbencoder.py --kb_path countries_kb.txt --vocab_from_kb --save_vocab
# Out:
# Creating vocabulary from last gameofthrones.txt knowledge base

# %% [markdown]
# Train a neural net to convert first-order logic atoms into meaningful numeric vectors. We call these vectors "embeddings," and the learned model the embedding model. The code creates random atoms and then uses a mechanism known as triplet loss to place unifying atoms closer together.
#
# Creates the files:
#
# *   rKB_model.pth - Saves the learned weights for the embedding model
# *   training_loss-45-106-2-50.png - A plot of the training loss after each epoch. This file's name depends on the vocabulary of your KB: the four numbers are number of predicates, number of constants, max arity of the predicates, and the embedding size used. If you changed the KB, you'll need to look up the name in your drive and update the code block that displays this file.

# %%
# !python kbencoder.py --kb_path countries_kb.txt --train_unification_model
# Out:
# Using cuda device
# Uni model embed size: 50
#  [████████████████████] 3500/3500 Anchors generated
#  [████████████████████] 70000/70000 Triplets generated
#  [█████---------------] 18067/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#  [██████████████------] 49391/70000 Triplet encodings
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#  [████████████████████] 70000/70000 Triplet encodings
# Early stopping triggered-------------] 37.9% Epoch | [Epoch 190/500, Training Loss: 0.0559, Validation Loss: 0.2910]
# Saved model.
# Saved plot.
# unification model generated

# %%
img = plt.imread('training_loss-45-106-2-50.png')
plt. imshow(img)

# %% [markdown]
# Generate a set of train and test queries from your knowledge base. This will also generate the deductive closure (all facts that can be inferred) of your KB using forward-chaining.
#
# Produces the files:
#
# *  all_facts.txt - A list of all facts that can be inferred from the KB. This is used to generate queries that are guaranteed to have an answer.
# *  train_queries.txt - A set of training queries where each will have at least one answer.
# *  test_queries.txt - A set of test queries where each will have at least one answer.

# %%
# !python kbencoder.py --kb_path countries_kb.txt -g
# Out:
# Generating facts list...
# Forward chaining depth: 1
# New facts: 442
# Forward chaining depth: 2
# New facts: 175
# Forward chaining depth: 3
# New facts: 82
# Forward chaining depth: 4
# New facts: 12
# Forward chaining depth: 5
# New facts: 1
# Forward chaining depth: 6
# New facts: 2
# Forward chaining depth: 7
#
# Facts list generated
# 714 total facts. Max depth = 6
#
# Number of queries: 200
# 100 training queries generated
# 100 testing queries generated

# %% [markdown]
# Create a training set for the scoring model. The examples will consist of goal, rule, score pairs, where a score of 1 means the rule can solve the goal, and 0 means it cannot. It runs the full set of training queries with a randomized backward-chaining process. This step can sometimes take a long time and is not able to take advantage of a GPU (with the countries_kb KB it took ~45 minutes).
#
# Creates a file:
# *  mr_train_examples.csv - Contains a line for each goal/rule/score example.

# %%
# !python kbencoder.py --kb_path countries_kb.txt -p
# Out:
# running training queries...
# Negative facts will be generated
# 1: [descendant(tommen_lannister, _EX6)]
# min depth: 5
# Nodes: 42249
# Answers: 10
#
# 2: [descendant(X, _EX0)]
# min depth: 5
# Nodes: 22123
# Answers: 208
#
# 3: [status(polliver, X), status(eddard_stark, X)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 4: [daughter(rhaella_targaryen, Z)]
# min depth: 3
# Nodes: 6
# Answers: 2
#
# 5: [descendant(maron_greyjoy, unknown_father_greyjoy)]
# Restart...
# Restart...
# Answers: 0
#
# 6: [descendant(X, Y), father(doran_martell, X), mother(Y, X), parent(Y, X)]
# min depth: 5
# Nodes: 21417
# Answers: 210
#
# 7: [ancestor(_EX3, Z)]
# Restart...
# min depth: 2
# Nodes: 100144
# Answers: 139
#
# 8: [child(Z, _EX1)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 9: [child(_EX0, catelyn_stark)]
# min depth: 2
# Nodes: 7
# Answers: 5
#
# 10: [ancestor(_EX5, _EX1)]
# Restart...
# min depth: 2
# Nodes: 100172
# Answers: 166
#
# 11: [daughter(_EX0, unknown_mother_sand_1)]
# min depth: 3
# Nodes: 35
# Answers: 1
#
# 12: [parent(X, Y), daughter(sansa_stark, X), descendant(Y, catelyn_stark), parent(X, robb_stark)]
# min depth: 1
# Nodes: 105
# Answers: 104
#
# 13: [parent(X, Y), status(X, alive), ancestor(Z, Y), ancestor(Z, nymeria_sand), descendant(nymeria_sand, Z)]
# min depth: 1
# Nodes: 105
# Answers: 104
#
# 14: [status(the_mountain, X), status(drogon, X)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 15: [son(_EX3, Y)]
# min depth: 3
# Nodes: 178
# Answers: 72
#
# 16: [descendant(X, Y), son(X, Y), son(trystane_martell, X), descendant(obara_sand, Y), son(X, lewyn_martell)]
# min depth: 3
# Nodes: 10332
# Answers: 226
#
# 17: [daughter(_EX2, _EX6)]
# min depth: 3
# Nodes: 134
# Answers: 28
#
# 18: [status(Y, X), status(Z, X), status(jon_snow, X), descendant(Z, balon_greyjoy)]
# min depth: 1
# Nodes: 80
# Answers: 79
#
# 19: [ancestor(Y, lancel_lannister)]
# Restart...
# min depth: 2
# Nodes: 100117
# Answers: 1
#
# 20: [ancestor(_EX2, X)]
# min depth: 2
# Nodes: 49126
# Answers: 210
#
# 21: [daughter(_EX4, unknown_mother_stark)]
# min depth: 3
# Nodes: 7
# Answers: 1
#
# 22: [son(X, Y), son(tyrion_lannister, X), ancestor(Y, Z), status(Z, dead)]
# min depth: 3
# Nodes: 121
# Answers: 72
#
# 23: [daughter(daenerys_targaryen, _EX4)]
# min depth: 3
# Nodes: 6
# Answers: 2
#
# 24: [status(X, Y), status(the_mountain, Y)]
# min depth: 1
# Nodes: 80
# Answers: 79
#
# 25: [father(rhaegar_targaryen, _EX2)]
# min depth: 3
# Nodes: 6
# Answers: 3
#
# 26: [ancestor(unknown_mother_greyjoy, _EX4)]
# Restart...
# min depth: 2
# Nodes: 30563
# Answers: 3
#
# 27: [descendant(X, jaime_lannister), parent(jaime_lannister, X), ancestor(jaime_lannister, X)]
# min depth: 3
# Nodes: 22917
# Answers: 3
#
# 28: [love(X, daenerys_targaryen), who_loved_daenerys(X)]
# min depth: 1
# Nodes: 6
# Answers: 5
#
# 29: [mother(cassana_estermont, _EX1)]
# min depth: 3
# Nodes: 6
# Answers: 3
#
# 30: [who_loved_daenerys_and_was_corresponded(X), who_loved_daenerys(X), love(X, daenerys_targaryen), love(daenerys_targaryen, X)]
# min depth: 3
# Nodes: 9
# Answers: 3
#
# 31: [child(balon_greyjoy, X), mother(X, aeron_greyjoy)]
# min depth: 2
# Nodes: 4
# Answers: 2
#
# 32: [mother(_EX2, aeron_greyjoy)]
# min depth: 3
# Nodes: 35
# Answers: 1
#
# 33: [ancestor(X, Y), descendant(rodrick_greyjoy, X), child(rodrick_greyjoy, X), parent(X, Y)]
# Restart...
# min depth: 2
# Nodes: 11027
# Answers: 210
#
# 34: [child(Z, _EX1)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 35: [mother(_EX1, _EX5)]
# min depth: 3
# Nodes: 155
# Answers: 49
#
# 36: [descendant(arya_stark, _EX2)]
# Restart...
# min depth: 3
# Nodes: 31618
# Answers: 4
#
# 37: [daughter(_EX3, unknown_mother_sand_2)]
# min depth: 3
# Nodes: 35
# Answers: 1
#
# 38: [who_loved_daenerys(X), love(X, Y), like_to_free_slaves(Y)]
# min depth: 2
# Nodes: 7
# Answers: 5
#
# 39: [status(thoros_of_myr, X), status(night_king, X)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 40: [ancestor(_EX4, _EX0)]
# Restart...
# min depth: 2
# Nodes: 100144
# Answers: 116
#
# 41: [child(Y, X), son(daeron_targaryen, X), child(viserys_targaryen, Y), parent(unknown_mother_targaryen, Y)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 42: [father(_EX0, benjen_stark)]
# min depth: 3
# Nodes: 50
# Answers: 1
#
# 43: [child(X, Y), descendant(X, eddard_stark), child(robb_stark, Y)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 44: [mother(X, rodrick_greyjoy)]
# min depth: 3
# Nodes: 35
# Answers: 1
#
# 45: [ancestor(_EX1, _EX3)]
# min depth: 2
# Nodes: 10414
# Answers: 236
#
# 46: [father(_EX3, Z)]
# min depth: 3
# Nodes: 160
# Answers: 54
#
# 47: [son(_EX5, balon_greyjoy)]
# min depth: 3
# Nodes: 9
# Answers: 3
#
# 48: [child(X, unknown_mother_greyjoy), descendant(X, unknown_father_greyjoy)]
# min depth: 2
# Nodes: 5
# Answers: 3
#
# 49: [descendant(sansa_stark, eddard_stark)]
# min depth: 3
# Nodes: 1785
# Answers: 1
#
# 50: [ancestor(X, duncan_targaryen), descendant(Y, X), ancestor(aegon_v_targaryen, Y)]
# Restart...
# min depth: 2
# Restart...
# min depth: 3
# Nodes: 26746
# Answers: 2
#
# 61: [descendant(robert_baratheon, _EX4)]
# Restart...
# min depth: 3
# Nodes: 500
# Answers: 2
#
# 62: [son(X, unknown_mother_stark), status(X, dead), descendant(bran_stark, X)]
# min depth: 3
# Nodes: 52
# Answers: 3
#
# 63: [ancestor(luthor_tyrell, Z)]
# Restart...
# min depth: 4
# Nodes: 10482
# Answers: 3
#
# 64: [descendant(cersei_lannister, _EX5)]
# min depth: 3
# Nodes: 4516
# Answers: 2
#
# 65: [status(melisandre, X), status(arya_stark, X), status(sansa_stark, X)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 66: [descendant(tyrion_lannister, unknown_mother_lannister)]
# Restart...
# min depth: 5
# Nodes: 137
# Answers: 1
#
# 67: [parent(mace_tyrell, X), daughter(X, Y), mother(Y, X), parent(Y, X), mother(Y, loras_tyrell)]
# min depth: 1
# Nodes: 3
# Answers: 2
#
# 68: [descendant(Z, X), father(Y, X), male(Y), descendant(tommen_lannister, Y), ancestor(unknown_mother_lannister, Z)]
# min depth: 3
# Nodes: 7750
# Answers: 220
#
# 69: [descendant(X, Y), descendant(X, Z), descendant(_EX0, Y), son(aeron_greyjoy, Z), descendant(_EX0, Z)]
# min depth: 5
# Nodes: 42669
# Answers: 234
#
# 70: [male(X), father(Y, X), descendant(X, Y), ancestor(Z, Y), child(lyanna_stark, Z)]
# min depth: 1
# Nodes: 48
# Answers: 47
#
# 71: [father(_EX1, ella_martell)]
# min depth: 3
# Nodes: 5
# Answers: 1
#
# 72: [descendant(X, Y), daughter(X, oberyn_martell), parent(Y, X), child(X, Y)]
# min depth: 3
# Nodes: 21910
# Answers: 200
#
# 73: [descendant(lancel_lannister, X), father(X, kevan_lannister)]
# Restart...
# min depth: 3
# Nodes: 33766
# Answers: 2
#
# 74: [child(Y, X), father(unknown_father_greyjoy, X), son(Y, alannys_harlaw)]
# min depth: 2
# Nodes: 106
# Answers: 104
#
# 75: [ancestor(ellaria_sand, X), ancestor(Y, X), ancestor(Y, obara_sand), parent(ellaria_sand, X)]
# Restart...
# Restart...
# min depth: 2
# Nodes: 20811
# Answers: 2
#
# 76: [parent(X, tyene_sand), descendant(Y, X), father(lewyn_martell, X), descendant(Y, unknown_mother_martell)]
# min depth: 1
# Nodes: 3
# Answers: 2
#
# 77: [ancestor(_EX0, _EX1)]
# min depth: 2
# Nodes: 62772
# Answers: 166
#
# 78: [descendant(Z, rickard_stark)]
# min depth: 5
# Nodes: 6777
# Answers: 12
#
# 79: [status(Y, X), status(elia_martell, X), who_brought_the_winter(Y), who_killed_dragons(Y)]
# min depth: 1
# Nodes: 80
# Answers: 79
#
# 80: [descendant(daenerys_targaryen, X), descendant(Y, X), male(Y), parent(rhaella_targaryen, Y)]
# min depth: 3
# Nodes: 158
# Answers: 6
#
# 81: [ancestor(rhaegar_targaryen, X), status(X, Y), status(tywin_lannister, Y), status(cassana_estermont, Y), status(duncan_targaryen, Y)]
# Restart...
# Restart...
# Answers: 0
#
# 82: [male(X), son(X, aegon_v_targaryen)]
# min depth: 1
# Nodes: 48
# Answers: 47
#
# 83: [love(X, Y), love(X, Z), daughter(X, rhaella_targaryen), love(Y, X), who_loved_daenerys(Z)]
# min depth: 1
# Nodes: 12
# Answers: 11
#
# 84: [descendant(Z, _EX4)]
# min depth: 3
# Nodes: 20578
# Answers: 178
#
# 85: [status(Y, X), status(alerie_hightower, X)]
# min depth: 1
# Nodes: 80
# Answers: 79
#
# 86: [ancestor(Y, X), father(kevan_lannister, X), child(tywin_lannister, Y)]
# Restart...
# min depth: 2
# Nodes: 90105
# Answers: 162
#
# 87: [descendant(_EX5, X)]
# min depth: 5
# Nodes: 21037
# Answers: 204
#
# 88: [descendant(rickon_stark, eddard_stark)]
# min depth: 3
# Nodes: 1362
# Answers: 1
#
# 89: [daughter(_EX5, _EX6)]
# min depth: 3
# Nodes: 134
# Answers: 28
#
# 90: [descendant(obara_sand, _EX1)]
# Restart...
# min depth: 5
# Nodes: 14140
# Answers: 6
#
# 91: [father(oberyn_martell, X), ancestor(oberyn_martell, X), status(X, Y), status(tytos_lannister, Y), status(tommen_lannister, Y)]
# min depth: 3
# Nodes: 12
# Answers: 5
#
# 92: [status(X, Z), daughter(Y, X), ancestor(aegon_v_targaryen, Y), status(eddard_stark, Z)]
# min depth: 1
# Nodes: 80
# Answers: 79
#
# 93: [descendant(X, tytos_lannister)]
# min depth: 5
# Nodes: 22306
# Answers: 15
#
# 94: [descendant(Y, X), descendant(rodrick_greyjoy, X), father(Z, Y), son(aeron_greyjoy, X), descendant(Y, Z)]
# min depth: 3
# Nodes: 21808
# Answers: 226
#
# 95: [who_brought_the_winter(X), night_walkers_king(X), kill(X, Y), creatures(Y), night_walker(X)]
# min depth: 3
# Nodes: 4
# Answers: 1
#
# 96: [son(Y, X), descendant(Z, X), son(Y, unknown_mother_greyjoy), father(X, euron_greyjoy), descendant(Z, alannys_harlaw)]
# min depth: 3
# Nodes: 178
# Answers: 72
#
# 97: [descendant(daeron_targaryen, aegon_v_targaryen)]
# Restart...
# Restart...
# Answers: 0
#
# 98: [child(rodrick_greyjoy, alannys_harlaw)]
# min depth: 2
# Nodes: 3
# Answers: 1
#
# 99: [child(_EX1, mellario_of_norvos)]
# min depth: 2
# Nodes: 3
# Answers: 1
#
# 100: [descendant(_EX1, _EX5)]
# min depth: 3
# Nodes: 10194
# Answers: 204
#
# Before removing duplicates: 1659568 examples
# After removing duplicates: 20592 examples
# Replicating pos examples 3 times
# pos len=16503, neg len=16503

# %% [markdown]
# Train the scoring model. This step will usually take several minutes, especially if you are not using a GPU (for the countries_kb KB, it takes about 30 minutes on CPU).
#
# Creates a file:
# * uni_mr_model.pt - Contains the weights for the learned scoring model

# %%
# !python nnreasoner.py --embed_type unification
# Out:
# States from vocab: vocab
# Num predicates: 45
# Max arity: 2
# Num constants: 106
# Num variables: 10
#
# Training unification
# Embed size: 50
# Reading examples from mr_train_examples.csv
# Parsing examples...
# Generating embeddings...
# Embedding input size: 277
#  [███████████████] 33005/33005 Prepping examples
# Loaded data...
# Using cuda device
# /opt/tljh/user/envs/cse327python311/lib/python3.11/site-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# 0	0.58900 (-)
# 50	0.34144 (-0.0042)
# 100	0.30218 (-0.0027)
# 150	0.28689 (-0.0019)
# 200	0.27448 (-0.0015)
# 250	0.26370 (-0.0012)
# 300	0.25767 (-0.0011)
# 350	0.24897 (-0.0009)
# 400	0.24486 (-0.0008)
# 450	0.23898 (-0.0007)
# 500	0.23522 (-0.0007)
# 550	0.22956 (-0.0006)
# 600	0.22531 (-0.0006)
# 650	0.22508 (-0.0005)
# 700	0.22217 (-0.0005)
# 750	0.22216 (-0.0004)
# 800	0.21567 (-0.0004)
# 850	0.21634 (-0.0004)
# 900	0.21680 (-0.0004)
# 950	0.21417 (-0.0003)
# 1000	0.21251 (-0.0003)
# 1050	0.21046 (-0.0003)
# 1100	0.20932 (-0.0003)
# 1150	0.20934 (-0.0003)
# 1200	0.20760 (-0.0003)
# 1250	0.20738 (-0.0003)
# 1300	0.20574 (-0.0002)
# 1350	0.20619 (-0.0002)
# 1400	0.20312 (-0.0002)
# 1450	0.20634 (-0.0002)
# 1500	0.20290 (-0.0002)
# 1550	0.20066 (-0.0002)
# 1600	0.20126 (-0.0002)
# 1650	0.20081 (-0.0002)
# 1700	0.20114 (-0.0002)
# 1750	0.20153 (-0.0002)
# 1800	0.20023 (-0.0002)
# 1850	0.19905 (-0.0002)
# 1900	0.19822 (-0.0002)
# 1950	0.19752 (-0.0002)
# 2000	0.19676 (-0.0001)
# 2050	0.19793 (-0.0001)
# 2100	0.19756 (-0.0001)
# 2150	0.19608 (-0.0001)
# 2200	0.19597 (-0.0001)
# 2250	0.19361 (-0.0001)
# 2300	0.19397 (-0.0001)
# 2350	0.19375 (-0.0001)
# 2400	0.19442 (-0.0001)
# 2450	0.19211 (-0.0001)
# 2500	0.19126 (-0.0001)
# 2550	0.19321 (-0.0001)
# 2599	0.19217 (-0.0001)
# Saved training loss figure.

# %%
img = plt.imread('guided_loss-unification45-106-2-50.png')
plt. imshow(img)

# %% [markdown]
# Evaluate the scoring model by running evaluate.py. We compare the standard backward-chaining algorithm (-s) with the one that uses our learned scoring model (-u).
#
# The output lists each query, and then provides a line that gives information about query execution. These are: number of nodes explored in the tree, depth of the solution, execution time in seconds, and the speed of exploring the tree (nodes per second).
#
# The names of the files produced depend on the KB used and the options selected. The code below produces the files:
#
# * std-45-106-2-50.csv - A CSV file with query results for the standard backward-chaining algorithm
# * ming-45-106-2-50.csv - A CSV file with query results for the learned reasoner. ming stands for "min scoring goal" and is the default strategy for deciding how to make use of the scores
#
# If you use a different knowledge base, you will likely get different file names that depend on the features of that KB's vocabulary.

# %%
# !python evaluate.py --kb countries_kb.txt -s
# !python evaluate.py --kb countries_kb.txt -u
# Out:
# using cuda device
# STANDARD
#
# Query 1: [who_loved_daenerys(X), love(X, Y), descendant(Y, aerys_targaryen)]
# 7 :: 6 - 00:00:00 (5808 nps)
#
# Query 2: [descendant(duncan_targaryen, unknown_mother_targaryen)]
# 4 :: 3 - 00:00:00 (5039 nps)
#
# Query 3: [status(Y, X), status(olenna_tyrell, X)]
# 3 :: 2 - 00:00:00 (2185 nps)
#
# Query 4: [descendant(Y, _EX3)]
# 4 :: 3 - 00:00:00 (2413 nps)
#
# Query 5: [ancestor(_EX6, sansa_stark)]
# 3 :: 2 - 00:00:00 (3918 nps)
#
# Query 6: [ancestor(unknown_mother_targaryen, X), ancestor(Y, X), parent(Y, viserys_targaryen)]
# 246 :: 7 - 00:00:00 (1410 nps)
#
# Query 7: [son(X, lyanna_stark), ancestor(rhaegar_targaryen, X)]
# 22 :: 5 - 00:00:00 (1876 nps)
#
# Query 8: [destroy(X, iron_throne), status(X, alive), destroy(X, capital), kill(X, Y), who_betrayed_daenerys(Y)]
# 7 :: 6 - 00:00:00 (8752 nps)
#
# Query 9: [descendant(mace_tyrell, X), ancestor(X, mace_tyrell)]
# 6 :: 5 - 00:00:00 (4197 nps)
#
# Query 10: [descendant(X, unknown_mother_stark), child(X, rickard_stark)]
# 6 :: 5 - 00:00:00 (3845 nps)
#
# Query 11: [ancestor(_EX5, _EX6)]
# 3 :: 2 - 00:00:00 (1578 nps)
#
# Query 12: [son(_EX6, _EX2)]
# 4 :: 3 - 00:00:00 (3851 nps)
#
# Query 13: [descendant(shireen_baratheon, Z)]
# 4 :: 3 - 00:00:00 (4821 nps)
#
# Query 14: [child(_EX3, Z)]
# 3 :: 2 - 00:00:00 (2667 nps)
#
# Query 15: [who_betrayed_daenerys(_EX3)]
# 3 :: 2 - 00:00:00 (22038 nps)
#
# Query 16: [descendant(X, Y), ancestor(Y, X), parent(Y, tyene_sand), parent(unknown_mother_sand_3, X), child(tyene_sand, Y)]
# 3311 :: 9 - 00:00:00 (6133 nps)
#
# Query 17: [descendant(X, aegon_v_targaryen)]
# 4 :: 3 - 00:00:00 (3922 nps)
#
# Query 18: [who_is_the_breaker_of_chains(_EX5)]
# 4 :: 3 - 00:00:00 (30683 nps)
#
# Query 19: [descendant(Z, _EX4)]
# 4 :: 3 - 00:00:00 (2292 nps)
#
# Query 20: [ancestor(Y, X), ancestor(Z, X), father(tytos_lannister, Y), ancestor(Z, tommen_lannister)]
# 5949 :: 11 - 00:00:00 (14626 nps)
#
# Query 21: [descendant(Y, X), mother(unknown_mother_martell, X), parent(lewyn_martell, X), parent(X, Y)]
# 153 :: 8 - 00:00:00 (9237 nps)
#
# Query 22: [kill(night_king, X), mother_dragons(Y, X), love(jorah_mormont, Y)]
# 4 :: 3 - 00:00:00 (12988 nps)
#
# Query 23: [father(_EX6, _EX0)]
# 5 :: 3 - 00:00:00 (2810 nps)
#
# Query 24: [betray(witch, X), daughter(X, aerys_targaryen)]
# 5 :: 4 - 00:00:00 (5092 nps)
#
# Query 25: [child(_EX6, _EX4)]
# 3 :: 2 - 00:00:00 (1849 nps)
#
# Query 26: [daughter(sarella_sand, _EX2)]
# 4 :: 3 - 00:00:00 (4276 nps)
#
# Query 27: [status(Z, X), status(Y, X), status(tyene_sand, X)]
# 4 :: 3 - 00:00:00 (1834 nps)
#
# Query 28: [descendant(X, Z), parent(Y, X), descendant(X, Y), child(tyrion_lannister, Z), daughter(X, Y)]
# 7981 :: 12 - 00:00:00 (25151 nps)
#
# Query 29: [descendant(obara_sand, Y)]
# 4 :: 3 - 00:00:00 (4881 nps)
#
# Query 30: [child(_EX4, _EX6)]
# 3 :: 2 - 00:00:00 (1944 nps)
#
# Query 31: [child(lancel_lannister, kevan_lannister)]
# 3 :: 2 - 00:00:00 (4009 nps)
#
# Query 32: [ancestor(_EX1, eddard_stark)]
# 3 :: 2 - 00:00:00 (4122 nps)
#
# Query 33: [daughter(Y, X), parent(X, Y), father(X, Y)]
# 10 :: 7 - 00:00:00 (3226 nps)
#
# Query 34: [daughter(lyanna_stark, Z)]
# 4 :: 3 - 00:00:00 (4544 nps)
#
# Query 35: [status(Y, X), status(benjen_stark, X), dragon(Y), status(Z, X), parent(jaime_lannister, Z)]
# 164 :: 5 - 00:00:00 (9544 nps)
#
# Query 36: [descendant(X, jaime_lannister), ancestor(Y, X), status(Y, dead)]
# 7 :: 6 - 00:00:00 (3159 nps)
#
# Query 37: [daughter(_EX4, Y)]
# 6 :: 3 - 00:00:00 (2626 nps)
#
# Query 38: [father(_EX1, aerys_targaryen)]
# 5 :: 3 - 00:00:00 (1308 nps)
#
# Query 39: [ancestor(Z, X), descendant(X, Y), father(Y, X), descendant(loras_tyrell, Z), status(Y, dead)]
# 1765 :: 14 - 00:00:00 (7247 nps)
#
# Query 40: [mother_dragons(X, viserion), ancestor(Y, X), child(Y, aegon_v_targaryen), kill(X, varys)]
# 7 :: 6 - 00:00:00 (7416 nps)
#
# Query 41: [descendant(Y, X), descendant(shireen_baratheon, X), son(Y, cassana_estermont)]
# 5333 :: 11 - 00:00:00 (22565 nps)
#
# Query 42: [ancestor(Y, X), descendant(X, Z), ancestor(Y, willem_lannister), descendant(myrcella_lannister, Z), father(jaime_lannister, X)]
# Query failed!!!
# 42471 :: 0 - 00:00:01 (27897 nps)
#
# Query 43: [son(viserys_targaryen, _EX5)]
# 4 :: 3 - 00:00:00 (3426 nps)
#
# Query 44: [who_brought_the_winter(X), who_killed_dragons(X), kill(arya_stark, X)]
# 8 :: 7 - 00:00:00 (24875 nps)
#
# Query 45: [child(X, catelyn_stark)]
# 3 :: 2 - 00:00:00 (3078 nps)
#
# Query 46: [child(Y, X), descendant(Y, X), ancestor(luthor_tyrell, Y)]
# 1961 :: 7 - 00:00:00 (45452 nps)
#
# Query 47: [ancestor(aegon_v_targaryen, Y)]
# 3 :: 2 - 00:00:00 (3109 nps)
#
# Query 48: [descendant(joffery_lannister, tywin_lannister)]
# 7 :: 5 - 00:00:00 (3233 nps)
#
# Query 49: [descendant(_EX6, rickard_stark)]
# 4 :: 3 - 00:00:00 (3939 nps)
#
# Query 50: [parent(Y, X), ancestor(X, nymeria_sand), child(ella_martell, Y), ancestor(lewyn_martell, X), son(X, Y)]
# 3223 :: 10 - 00:00:00 (19656 nps)
#
# Query 51: [status(elia_martell, X), status(Y, X), status(myrcella_lannister, X), ancestor(tytos_lannister, Y), status(brandon_stark, X)]
# 384 :: 8 - 00:00:00 (7444 nps)
#
# Query 52: [ancestor(X, tywin_lannister), ancestor(X, cersei_lannister)]
# 8 :: 6 - 00:00:00 (2763 nps)
#
# Query 53: [descendant(_EX6, _EX4)]
# 4 :: 3 - 00:00:00 (2792 nps)
#
# Query 54: [father(_EX1, X)]
# 5 :: 3 - 00:00:00 (5132 nps)
#
# Query 55: [ancestor(_EX2, _EX5)]
# 3 :: 2 - 00:00:00 (1703 nps)
#
# Query 56: [descendant(_EX1, _EX0)]
# 4 :: 3 - 00:00:00 (3004 nps)
#
# Query 57: [descendant(_EX1, _EX2)]
# 4 :: 3 - 00:00:00 (3096 nps)
#
# Query 58: [descendant(Z, _EX6)]
# 4 :: 3 - 00:00:00 (3067 nps)
#
# Query 59: [ancestor(unknown_mother_stark, _EX0)]
# 3 :: 2 - 00:00:00 (3192 nps)
#
# Query 60: [status(the_hound, X), status(the_mountain, X)]
# 3 :: 2 - 00:00:00 (2491 nps)
#
# Query 61: [ancestor(joanna_lannister, _EX4)]
# 3 :: 2 - 00:00:00 (3091 nps)
#
# Query 62: [father(_EX3, rodrick_greyjoy)]
# 8 :: 3 - 00:00:00 (2148 nps)
#
# Query 63: [who_killed_the_king_baratheon(_EX5)]
# 3 :: 2 - 00:00:00 (22291 nps)
#
# Query 64: [son(balon_greyjoy, _EX1)]
# 4 :: 3 - 00:00:00 (3827 nps)
#
# Query 65: [ancestor(_EX2, _EX4)]
# 3 :: 2 - 00:00:00 (1473 nps)
#
# Query 66: [descendant(_EX2, _EX0)]
# 4 :: 3 - 00:00:00 (3077 nps)
#
# Query 67: [descendant(bran_stark, _EX4)]
# 4 :: 3 - 00:00:00 (4975 nps)
#
# Query 68: [descendant(Y, aerys_targaryen)]
# 4 :: 3 - 00:00:00 (4008 nps)
#
# Query 69: [descendant(tyene_sand, X), descendant(ella_martell, X), ancestor(X, trystane_martell)]
# 99 :: 12 - 00:00:00 (10020 nps)
#
# Query 70: [ancestor(_EX1, _EX3)]
# 3 :: 2 - 00:00:00 (159 nps)
#
# Query 71: [who_betrayed_daenerys(varys)]
# 3 :: 2 - 00:00:00 (18979 nps)
#
# Query 72: [descendant(_EX4, _EX5)]
# 4 :: 3 - 00:00:00 (3109 nps)
#
# Query 73: [parent(ellaria_sand, X), child(X, ellaria_sand)]
# 4 :: 3 - 00:00:00 (2224 nps)
#
# Query 74: [father(Y, benjen_stark)]
# 33 :: 3 - 00:00:00 (1500 nps)
#
# Query 75: [daughter(daenerys_targaryen, rhaella_targaryen)]
# 4 :: 3 - 00:00:00 (4140 nps)
#
# Query 76: [ancestor(tytos_lannister, X), descendant(X, tywin_lannister)]
# 181 :: 7 - 00:00:00 (5801 nps)
#
# Query 77: [descendant(X, Y), ancestor(Y, X), father(lewyn_martell, Y)]
# 2921 :: 8 - 00:00:00 (55343 nps)
#
# Query 78: [father(stannis_baratheon, _EX0)]
# 4 :: 3 - 00:00:00 (3086 nps)
#
# Query 79: [mother(alannys_harlaw, rodrick_greyjoy)]
# 4 :: 3 - 00:00:00 (4039 nps)
#
# Query 80: [status(ilyn_payne, X), status(bran_stark, X), status(the_hound, X)]
# 4 :: 3 - 00:00:00 (2223 nps)
#
# Query 81: [ancestor(X, rhaenys_targaryen), descendant(Y, X), descendant(rhaenys_targaryen, X), male(Y)]
# 67 :: 9 - 00:00:00 (2878 nps)
#
# Query 82: [son(mace_tyrell, _EX6)]
# 4 :: 3 - 00:00:00 (3759 nps)
#
# Query 83: [son(Y, _EX0)]
# 4 :: 3 - 00:00:00 (5264 nps)
#
# Query 84: [ancestor(_EX0, Y)]
# 3 :: 2 - 00:00:00 (14 nps)
#
# Query 85: [descendant(willem_lannister, X), ancestor(X, Y), son(Y, Z), descendant(Y, Z), status(Z, dead)]
# 13 :: 12 - 00:00:00 (3149 nps)
#
# Query 86: [ancestor(X, Y), descendant(jon_snow, X), daughter(Y, catelyn_stark)]
# 10869 :: 12 - 00:00:00 (26642 nps)
#
# Query 87: [descendant(X, _EX2)]
# 4 :: 3 - 00:00:00 (3330 nps)
#
# Query 88: [who_betrayed_daenerys(Y)]
# 3 :: 2 - 00:00:00 (20035 nps)
#
# Query 89: [son(duncan_targaryen, X), parent(X, Y), child(Y, X)]
# 7 :: 6 - 00:00:00 (2621 nps)
#
# Query 90: [descendant(_EX6, _EX4)]
# 4 :: 3 - 00:00:00 (49424 nps)
#
# Query 91: [child(tyrion_lannister, _EX5)]
# 3 :: 2 - 00:00:00 (4000 nps)
#
# Query 92: [son(_EX1, _EX2)]
# 4 :: 3 - 00:00:00 (38864 nps)
#
# Query 93: [descendant(aeron_greyjoy, _EX2)]
# 4 :: 3 - 00:00:00 (1274 nps)
#
# Query 94: [mother(Y, _EX2)]
# 4 :: 3 - 00:00:00 (4077 nps)
#
# Query 95: [mother(unknown_mother_lannister, _EX6)]
# 4 :: 3 - 00:00:00 (3399 nps)
#
# Query 96: [ancestor(_EX2, _EX5)]
# 3 :: 2 - 00:00:00 (38918 nps)
#
# Query 97: [ancestor(_EX4, tommen_lannister)]
# 3 :: 2 - 00:00:00 (3922 nps)
#
# Query 98: [daughter(_EX5, tywin_lannister)]
# 9 :: 3 - 00:00:00 (2117 nps)
#
# Query 99: [descendant(kevan_lannister, unknown_mother_lannister)]
# 4 :: 3 - 00:00:00 (5026 nps)
#
# Query 100: [child(rhaella_targaryen, aegon_v_targaryen)]
# 3 :: 2 - 00:00:00 (4017 nps)
#
# std: 874.92 nodes/query
# 1 queries failed
# Time to run all queries: 4.618429666999999
# using cuda device
# UNITY: ming
# 	Embedding Model: rKB_model.pth
# 	Scoring Model: uni_mr_model.pt
#
# 	Control: mingoal
# 	Rule Eval: Max Rule
# Learned Embedding: Network using cuda
# /opt/tljh/user/envs/cse327python311/lib/python3.11/site-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# Query 1: [who_loved_daenerys(X), love(X, Y), descendant(Y, aerys_targaryen)]
# 7 :: 6 - 00:00:00 (12 nps)
#
# Query 2: [descendant(duncan_targaryen, unknown_mother_targaryen)]
# 4 :: 3 - 00:00:00 (351 nps)
#
# Query 3: [status(Y, X), status(olenna_tyrell, X)]
# 3 :: 2 - 00:00:00 (12 nps)
#
# Query 4: [descendant(Y, _EX3)]
# 4 :: 3 - 00:00:00 (22 nps)
#
# Query 5: [ancestor(_EX6, sansa_stark)]
# 3 :: 2 - 00:00:00 (323 nps)
#
# Query 6: [ancestor(unknown_mother_targaryen, X), ancestor(Y, X), parent(Y, viserys_targaryen)]
# 21 :: 7 - 00:00:00 (26 nps)
#
# Query 7: [son(X, lyanna_stark), ancestor(rhaegar_targaryen, X)]
# 6 :: 5 - 00:00:00 (231 nps)
#
# Query 8: [destroy(X, iron_throne), status(X, alive), destroy(X, capital), kill(X, Y), who_betrayed_daenerys(Y)]
# 7 :: 6 - 00:00:00 (103 nps)
#
# Query 9: [descendant(mace_tyrell, X), ancestor(X, mace_tyrell)]
# 4 :: 3 - 00:00:00 (234 nps)
#
# Query 10: [descendant(X, unknown_mother_stark), child(X, rickard_stark)]
# 6 :: 5 - 00:00:00 (211 nps)
#
# Query 11: [ancestor(_EX5, _EX6)]
# 3 :: 2 - 00:00:00 (17 nps)
#
# Query 12: [son(_EX6, _EX2)]
# 9 :: 3 - 00:00:00 (36 nps)
#
# Query 13: [descendant(shireen_baratheon, Z)]
# 4 :: 3 - 00:00:00 (355 nps)
#
# Query 14: [child(_EX3, Z)]
# 3 :: 2 - 00:00:00 (17 nps)
#
# Query 15: [who_betrayed_daenerys(_EX3)]
# 3 :: 2 - 00:00:00 (286 nps)
#
# Query 16: [descendant(X, Y), ancestor(Y, X), parent(Y, tyene_sand), parent(unknown_mother_sand_3, X), child(tyene_sand, Y)]
# 8 :: 7 - 00:00:00 (104 nps)
#
# Query 17: [descendant(X, aegon_v_targaryen)]
# 4 :: 3 - 00:00:00 (258 nps)
#
# Query 18: [who_is_the_breaker_of_chains(_EX5)]
# 4 :: 3 - 00:00:00 (414 nps)
#
# Query 19: [descendant(Z, _EX4)]
# 4 :: 3 - 00:00:00 (22 nps)
#
# Query 20: [ancestor(Y, X), ancestor(Z, X), father(tytos_lannister, Y), ancestor(Z, tommen_lannister)]
# 2918 :: 11 - 00:00:30 (95 nps)
#
# Query 21: [descendant(Y, X), mother(unknown_mother_martell, X), parent(lewyn_martell, X), parent(X, Y)]
# 8 :: 7 - 00:00:00 (33 nps)
#
# Query 22: [kill(night_king, X), mother_dragons(Y, X), love(jorah_mormont, Y)]
# 6 :: 3 - 00:00:00 (342 nps)
#
# Query 23: [father(_EX6, _EX0)]
# 5 :: 3 - 00:00:00 (26 nps)
#
# Query 24: [betray(witch, X), daughter(X, aerys_targaryen)]
# 5 :: 4 - 00:00:00 (81 nps)
#
# Query 25: [child(_EX6, _EX4)]
# 3 :: 2 - 00:00:00 (16 nps)
#
# Query 26: [daughter(sarella_sand, _EX2)]
# 4 :: 3 - 00:00:00 (315 nps)
#
# Query 27: [status(Z, X), status(Y, X), status(tyene_sand, X)]
# 4 :: 3 - 00:00:00 (11 nps)
#
# Query 28: [descendant(X, Z), parent(Y, X), descendant(X, Y), child(tyrion_lannister, Z), daughter(X, Y)]
# 19 :: 11 - 00:00:00 (44 nps)
#
# Query 29: [descendant(obara_sand, Y)]
# 4 :: 3 - 00:00:00 (332 nps)
#
# Query 30: [child(_EX4, _EX6)]
# 3 :: 2 - 00:00:00 (16 nps)
#
# Query 31: [child(lancel_lannister, kevan_lannister)]
# 3 :: 2 - 00:00:00 (566 nps)
#
# Query 32: [ancestor(_EX1, eddard_stark)]
# 3 :: 2 - 00:00:00 (321 nps)
#
# Query 33: [daughter(Y, X), parent(X, Y), father(X, Y)]
# 26 :: 6 - 00:00:00 (84 nps)
#
# Query 34: [daughter(lyanna_stark, Z)]
# 4 :: 3 - 00:00:00 (380 nps)
#
# Query 35: [status(Y, X), status(benjen_stark, X), dragon(Y), status(Z, X), parent(jaime_lannister, Z)]
# 7 :: 5 - 00:00:00 (15 nps)
#
# Query 36: [descendant(X, jaime_lannister), ancestor(Y, X), status(Y, dead)]
# 7 :: 6 - 00:00:00 (29 nps)
#
# Query 37: [daughter(_EX4, Y)]
# 5 :: 3 - 00:00:00 (22 nps)
#
# Query 38: [father(_EX1, aerys_targaryen)]
# 4 :: 3 - 00:00:00 (57 nps)
#
# Query 39: [ancestor(Z, X), descendant(X, Y), father(Y, X), descendant(loras_tyrell, Z), status(Y, dead)]
# 12 :: 11 - 00:00:00 (13 nps)
#
# Query 40: [mother_dragons(X, viserion), ancestor(Y, X), child(Y, aegon_v_targaryen), kill(X, varys)]
# 7 :: 6 - 00:00:00 (200 nps)
#
# Query 41: [descendant(Y, X), descendant(shireen_baratheon, X), son(Y, cassana_estermont)]
# 306 :: 11 - 00:00:01 (179 nps)
#
# Query 42: [ancestor(Y, X), descendant(X, Z), ancestor(Y, willem_lannister), descendant(myrcella_lannister, Z), father(jaime_lannister, X)]
# Query failed!!!
# 10080 :: 0 - 00:00:36 (273 nps)
#
# Query 43: [son(viserys_targaryen, _EX5)]
# 4 :: 3 - 00:00:00 (391 nps)
#
# Query 44: [who_brought_the_winter(X), who_killed_dragons(X), kill(arya_stark, X)]
# 8 :: 7 - 00:00:00 (264 nps)
#
# Query 45: [child(X, catelyn_stark)]
# 3 :: 2 - 00:00:00 (242 nps)
#
# Query 46: [child(Y, X), descendant(Y, X), ancestor(luthor_tyrell, Y)]
# 7 :: 6 - 00:00:00 (179 nps)
#
# Query 47: [ancestor(aegon_v_targaryen, Y)]
# 3 :: 2 - 00:00:00 (220 nps)
#
# Query 48: [descendant(joffery_lannister, tywin_lannister)]
# 7 :: 5 - 00:00:00 (178 nps)
#
# Query 49: [descendant(_EX6, rickard_stark)]
# 4 :: 3 - 00:00:00 (279 nps)
#
# Query 50: [parent(Y, X), ancestor(X, nymeria_sand), child(ella_martell, Y), ancestor(lewyn_martell, X), son(X, Y)]
# 290047 :: 10 - 00:01:00 (4817 nps)
#
# Query 51: [status(elia_martell, X), status(Y, X), status(myrcella_lannister, X), ancestor(tytos_lannister, Y), status(brandon_stark, X)]
# 7 :: 6 - 00:00:00 (147 nps)
#
# Query 52: [ancestor(X, tywin_lannister), ancestor(X, cersei_lannister)]
# 9 :: 5 - 00:00:00 (21 nps)
#
# Query 53: [descendant(_EX6, _EX4)]
# 4 :: 3 - 00:00:00 (21 nps)
#
# Query 54: [father(_EX1, X)]
# 4 :: 3 - 00:00:00 (21 nps)
#
# Query 55: [ancestor(_EX2, _EX5)]
# 3 :: 2 - 00:00:00 (16 nps)
#
# Query 56: [descendant(_EX1, _EX0)]
# 4 :: 3 - 00:00:00 (21 nps)
#
# Query 57: [descendant(_EX1, _EX2)]
# 4 :: 3 - 00:00:00 (21 nps)
#
# Query 58: [descendant(Z, _EX6)]
# 4 :: 3 - 00:00:00 (21 nps)
#
# Query 59: [ancestor(unknown_mother_stark, _EX0)]
# 3 :: 2 - 00:00:00 (229 nps)
#
# Query 60: [status(the_hound, X), status(the_mountain, X)]
# 3 :: 2 - 00:00:00 (366 nps)
#
# Query 61: [ancestor(joanna_lannister, _EX4)]
# 3 :: 2 - 00:00:00 (269 nps)
#
# Query 62: [father(_EX3, rodrick_greyjoy)]
# 4 :: 3 - 00:00:00 (54 nps)
#
# Query 63: [who_killed_the_king_baratheon(_EX5)]
# 3 :: 2 - 00:00:00 (823 nps)
#
# Query 64: [son(balon_greyjoy, _EX1)]
# 4 :: 3 - 00:00:00 (478 nps)
#
# Query 65: [ancestor(_EX2, _EX4)]
# 3 :: 2 - 00:00:00 (16 nps)
#
# Query 66: [descendant(_EX2, _EX0)]
# 4 :: 3 - 00:00:00 (21 nps)
#
# Query 67: [descendant(bran_stark, _EX4)]
# 4 :: 3 - 00:00:00 (330 nps)
#
# Query 68: [descendant(Y, aerys_targaryen)]
# 4 :: 3 - 00:00:00 (36624 nps)
#
# Query 69: [descendant(tyene_sand, X), descendant(ella_martell, X), ancestor(X, trystane_martell)]
# 2895 :: 12 - 00:00:01 (2382 nps)
#
# Query 70: [ancestor(_EX1, _EX3)]
# 3 :: 2 - 00:00:00 (17 nps)
#
# Query 71: [who_betrayed_daenerys(varys)]
# 3 :: 2 - 00:00:00 (743 nps)
#
# Query 72: [descendant(_EX4, _EX5)]
# 4 :: 3 - 00:00:00 (20 nps)
#
# Query 73: [parent(ellaria_sand, X), child(X, ellaria_sand)]
# 4 :: 3 - 00:00:00 (336 nps)
#
# Query 74: [father(Y, benjen_stark)]
# 4 :: 3 - 00:00:00 (56 nps)
#
# Query 75: [daughter(daenerys_targaryen, rhaella_targaryen)]
# 4 :: 3 - 00:00:00 (596 nps)
#
# Query 76: [ancestor(tytos_lannister, X), descendant(X, tywin_lannister)]
# 54898 :: 6 - 00:00:03 (16891 nps)
#
# Query 77: [descendant(X, Y), ancestor(Y, X), father(lewyn_martell, Y)]
# 8 :: 7 - 00:00:00 (150 nps)
#
# Query 78: [father(stannis_baratheon, _EX0)]
# 4 :: 3 - 00:00:00 (385 nps)
#
# Query 79: [mother(alannys_harlaw, rodrick_greyjoy)]
# 4 :: 3 - 00:00:00 (409 nps)
#
# Query 80: [status(ilyn_payne, X), status(bran_stark, X), status(the_hound, X)]
# 4 :: 3 - 00:00:00 (325 nps)
#
# Query 81: [ancestor(X, rhaenys_targaryen), descendant(Y, X), descendant(rhaenys_targaryen, X), male(Y)]
# 10 :: 9 - 00:00:00 (19 nps)
#
# Query 82: [son(mace_tyrell, _EX6)]
# 4 :: 3 - 00:00:00 (360 nps)
#
# Query 83: [son(Y, _EX0)]
# 5 :: 3 - 00:00:00 (28 nps)
#
# Query 84: [ancestor(_EX0, Y)]
# 3 :: 2 - 00:00:00 (570 nps)
#
# Query 85: [descendant(willem_lannister, X), ancestor(X, Y), son(Y, Z), descendant(Y, Z), status(Z, dead)]
# 13 :: 12 - 00:00:01 (6 nps)
#
# Query 86: [ancestor(X, Y), descendant(jon_snow, X), daughter(Y, catelyn_stark)]
# 10053 :: 12 - 00:00:06 (1605 nps)
#
# Query 87: [descendant(X, _EX2)]
# 4 :: 3 - 00:00:00 (21 nps)
#
# Query 88: [who_betrayed_daenerys(Y)]
# 3 :: 2 - 00:00:00 (297 nps)
#
# Query 89: [son(duncan_targaryen, X), parent(X, Y), child(Y, X)]
# 24 :: 5 - 00:00:00 (111 nps)
#
# Query 90: [descendant(_EX6, _EX4)]
# 4 :: 3 - 00:00:00 (20162 nps)
#
# Query 91: [child(tyrion_lannister, _EX5)]
# 3 :: 2 - 00:00:00 (433 nps)
#
# Query 92: [son(_EX1, _EX2)]
# 8 :: 3 - 00:00:00 (42 nps)
#
# Query 93: [descendant(aeron_greyjoy, _EX2)]
# 4 :: 3 - 00:00:00 (368 nps)
#
# Query 94: [mother(Y, _EX2)]
# 4 :: 3 - 00:00:00 (17 nps)
#
# Query 95: [mother(unknown_mother_lannister, _EX6)]
# 4 :: 3 - 00:00:00 (320 nps)
#
# Query 96: [ancestor(_EX2, _EX5)]
# 3 :: 2 - 00:00:00 (19250 nps)
#
# Query 97: [ancestor(_EX4, tommen_lannister)]
# 3 :: 2 - 00:00:00 (321 nps)
#
# Query 98: [daughter(_EX5, tywin_lannister)]
# 4 :: 3 - 00:00:00 (74 nps)
#
# Query 99: [descendant(kevan_lannister, unknown_mother_lannister)]
# 4 :: 3 - 00:00:00 (379 nps)
#
# Query 100: [child(rhaella_targaryen, aegon_v_targaryen)]
# 3 :: 2 - 00:00:00 (647 nps)
#
# ming: 3717.05 nodes/query
# 1 queries failed
# Time to run all queries: 152.92660947200008

# %% [markdown]
# The results suggest only minor improvements for the countries_kb KB: on average 3.75 vs. 4.39 node per query when I ran it. You may get different results due to the randomization of training and random selection of test queries. Larger, more complex KBs can see much larger improvements, sometimes an order of magnitude or more.
#
# The code below shows the first 10 lines of each query result file. A given line has:
# * query sequence number
# * configuration name
# * number of nodes explored
# * depth of solution (0 if no solution found)
# * did the system find a solution (true/false)
# * time in seconds
#
# You can import these files into a spreadsheet in order to create plots or summary statistics.

# %%
# !head std-45-106-2-50.csv
# !head ming-45-106-2-50.csv
# Out:
# query,std reasoner,std nodes explored,std min depth,success,time
# 1,std,7,6,True,0.0012051809999995555
# 2,std,4,3,True,0.0007937890000002668
# 3,std,3,2,True,0.001372373000000593
# 4,std,4,3,True,0.0016571270000005356
# 5,std,3,2,True,0.0007655609999996926
# 6,std,246,7,True,0.17442084199999996
# 7,std,22,5,True,0.011725049999999904
# 8,std,7,6,True,0.0007997640000008133
# 9,std,6,5,True,0.0014295710000000739
# query,ming reasoner,ming nodes explored,ming min depth,success,time
# 1,ming,7,6,True,0.5392307470000004
# 2,ming,4,3,True,0.011384119000000581
# 3,ming,3,2,True,0.2332218810000004
# 4,ming,4,3,True,0.17915934100000008
# 5,ming,3,2,True,0.00927385600000008
# 6,ming,21,7,True,0.7831454939999993
# 7,ming,6,5,True,0.02586842600000061
# 8,ming,7,6,True,0.0678647520000002
# 9,ming,4,3,True,0.01704836100000051
