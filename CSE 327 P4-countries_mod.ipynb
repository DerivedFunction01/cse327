# %% [markdown]
# The block below imports a necessary module and checks if you are in the right directory. If you do not see a list of python files when you run the block, please make sure you have uploaded the zip file and unzipped it.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# If you want to create a random knowledge base, run the following code.
#
# Creates the files:
#
# * randomKB.txt - A random KB generated using 10 predicates and 100 constants.
# * vocab.pkl - Indexes the full set of predicates, constants and variables used by the knowledge base.

# %%
# !python kbencoder.py --generate_kb --new_vocab --save_vocab
# !head randomKB.txt

# %% [markdown]
# The following code prepares an existing knowledge base (KB) for use. To use a KB of your choosing, replace countries_kb.txt with the file name of any KB you want to use.
#
# Creates the file:
#
# *   vocab.pkl - Indexes the full set of predicates, constants and variables used by the knowledge base.

# %%
# !mkdir -p countriesmod

# %%
# !cd countriesmod && python ../kbencoder.py --kb_path ../countries/countries_kb.txt --vocab_from_kb --save_vocab
# Out:
# Creating vocabulary from last ../countries/countries_kb.txt knowledge base

# %% [markdown]
# Train a neural net to convert first-order logic atoms into meaningful numeric vectors. We call these vectors "embeddings," and the learned model the embedding model. The code creates random atoms and then uses a mechanism known as triplet loss to place unifying atoms closer together.
#
# Creates the files:
#
# *   rKB_model.pth - Saves the learned weights for the embedding model
# *   training_loss-45-106-2-50.png - A plot of the training loss after each epoch. This file's name depends on the vocabulary of your KB: the four numbers are number of predicates, number of constants, max arity of the predicates, and the embedding size used. If you changed the KB, you'll need to look up the name in your drive and update the code block that displays this file.

# %%
# !cd countriesmod && python ../kbencoder.py --kb_path ../countries/countries_kb.txt --train_unification_model --embed_model_path rKB_model.pth
# Out:
# Using cuda device
# Uni model embed size: 50
#  [████████████████████] 3500/3500 Anchors generated
#  [████████████████████] 70000/70000 Triplets generated
#  [████████████████████] 70000/70000 Triplet encodings
#  [█----------------------------------] 3.4% Epoch | [Epoch 18/500, Training Loss: 0.3003, Validation Loss: 0.4399]

# %%
from pathlib import Path
import matplotlib.pyplot as plt

img_paths = sorted(Path("countriesmod").glob("training_loss*.png"))
img = plt.imread(img_paths[0])
plt.figure(figsize=(8, 5))
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# Generate a set of train and test queries from your knowledge base. This will also generate the deductive closure (all facts that can be inferred) of your KB using forward-chaining.
#
# Produces the files:
#
# *  all_facts.txt - A list of all facts that can be inferred from the KB. This is used to generate queries that are guaranteed to have an answer.
# *  train_queries.txt - A set of training queries where each will have at least one answer.
# *  test_queries.txt - A set of test queries where each will have at least one answer.

# %%
# !cd countriesmod && python ../kbencoder.py --kb_path ../countries/countries_kb.txt -g
# Out:
# Generating facts list...
# Forward chaining depth: 1
# New facts: 17818
# Forward chaining depth: 2
# New facts: 2254
# Forward chaining depth: 3
# New facts: 3870
# Forward chaining depth: 4
# New facts: 5176
# Forward chaining depth: 5
#
# Facts list generated
# 29118 total facts. Max depth = 4
#
# Number of queries: 200
# 100 training queries generated
# 100 testing queries generated

# %% [markdown]
# Create a training set for the scoring model. The examples will consist of goal, rule, score pairs, where a score of 1 means the rule can solve the goal, and 0 means it cannot. It runs the full set of training queries with a randomized backward-chaining process. This step can sometimes take a long time and is not able to take advantage of a GPU (with the countries_kb KB it took ~45 minutes).
#
# Creates a file:
# *  mr_train_examples.csv - Contains a line for each goal/rule/score example.

# %%
# !cd countriesmod && python ../kbencoder.py --kb_path ../countries/countries_kb.txt -p
# Out:
# running training queries...
# Negative facts will be generated
# 1: [cityInRegion(C, City), capitalCity(C), locatedIn(zimbabwe, City)]
# min depth: 3
# Nodes: 510
# Answers: 313
#
# 2: [cityInRegion(C, asia), capitalCity(C)]
# min depth: 3
# Nodes: 82
# Answers: 50
#
# 3: [sameRegion(L, Region)]
# min depth: 3
# Nodes: 1030
# Answers: 1000
#
# 4: [officialLanguage(maldives, C)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 5: [sameRegion(Org, Continent)]
# min depth: 3
# Nodes: 1030
# Answers: 1000
#
# 6: [sameRegion(C, egypt), sameRegion(C, rwanda), sameRegion(eswatini, C)]
# min depth: 3
# Nodes: 110
# Answers: 106
#
# 7: [sameRegion(R, O)]
# min depth: 3
# Nodes: 1031
# Answers: 1000
#
# 8: [cityIn(pyongyang, C), threeBorderTrip(City, C), threeBorderTrip(afghanistan, City)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 9: [officialLanguage(iraq, C)]
# min depth: 1
# Nodes: 3
# Answers: 2
#
# 10: [threeBorderTrip(X, Org)]
# min depth: 8
# Nodes: 1597
# Answers: 1000
#
# 11: [currencyOf(C, City), fourBorderTrip(uganda, C), sameRegion(guinea_bissau, C)]
# min depth: 1
# Nodes: 196
# Answers: 195
#
# 12: [capitalCity(C), capitalInContinent(C, asia), cityInRegion(C, asia), capitalOf(City, C), fourBorderTrip(City, City)]
# min depth: 2
# Nodes: 197
# Answers: 195
#
# 13: [sameRegion(Region, Z)]
# min depth: 3
# Nodes: 1027
# Answers: 1000
#
# 14: [threeBorderTrip(O, R)]
# min depth: 8
# Nodes: 1600
# Answers: 1000
#
# 15: [sameRegion(C, croatia), threeBorderTrip(slovakia, C)]
# min depth: 3
# Nodes: 241
# Answers: 44
#
# 16: [sharesLanguage(City, Country)]
# min depth: 3
# Nodes: 1041
# Answers: 1000
#
# 17: [sharesLanguage(V, Continent)]
# min depth: 3
# Nodes: 1059
# Answers: 1000
#
# 18: [capitalInAlliance(City, C), twoStepBorderNeighborAlliance(nepal, C), cityInAlliance(City, Continent), cityInAllianceAndRegion(dhaka, Continent, asia)]
# min depth: 3
# Nodes: 302
# Answers: 105
#
# 19: [currencyOf(C, uae_dirham), sameAlliance(C, C), sameRegion(syria, C)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 20: [cityInAllianceAndRegion(City, eu, C), capitalInAllianceAndRegion(bratislava, nato, C), cityInAlliance(City, nato)]
# min depth: 4
# Nodes: 665
# Answers: 37
#
# 21: [sameRegion(C, mozambique), officialLanguage(C, spanish)]
# min depth: 3
# Nodes: 242
# Answers: 45
#
# 22: [threeBorderTrip(Continent, R)]
# min depth: 8
# Nodes: 25735
# Answers: 1000
#
# 23: [sameRegion(Neighbor, Country)]
# min depth: 3
# Nodes: 1026
# Answers: 1000
#
# 24: [sameRegion(C, V)]
# min depth: 3
# Nodes: 1030
# Answers: 1000
#
# 25: [sameRegion(C, portugal), sameRegion(City, C), fourBorderTrip(mongolia, City)]
# min depth: 3
# Nodes: 250
# Answers: 53
#
# 26: [cityInAllianceAndRegion(City, C, europe), countryInAllianceAndRegion(colombia, C, south_america), memberOf(chile, C), countryInAllianceAndRegion(argentina, C, south_america), cityInAlliance(City, eu)]
# min depth: 4
# Nodes: 265
# Answers: 100
#
# 27: [twoBorderTrip(Region, V)]
# min depth: 5
# Nodes: 1626
# Answers: 1000
#
# 28: [currencyOf(C, turkmen_manat), sameRegion(C, City), threeBorderTrip(City, Continent), fourBorderTrip(myanmar, Continent), sameRegion(thailand, Continent)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 29: [cityInContinent(C, City), cityInAllianceAndRegion(C, g20, City), capitalInContinent(phnom_penh, City)]
# min depth: 3
# Nodes: 628
# Answers: 313
#
# 30: [capitalOf(chad, C), capitalInContinent(C, africa)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 31: [sameRegion(C, City), sameRegion(C, Continent), sharesLanguage(City, india), sameRegion(Continent, saint_vincent_and_the_grenadines), sameAlliance(italy, Continent)]
# min depth: 3
# Nodes: 1034
# Answers: 1000
#
# 32: [twoBorderTrip(Org, X)]
# min depth: 5
# Nodes: 1581
# Answers: 1000
#
# 33: [cityInAllianceAndRegion(C, Continent, europe), cityIn(C, City), fourBorderTrip(City, sweden), twoStepBorderNeighborAlliance(turkey, Continent)]
# min depth: 4
# Nodes: 386
# Answers: 100
#
# 34: [cityInContinent(City, C), capitalInContinent(ouagadougou, C), cityInRegion(City, C)]
# min depth: 3
# Nodes: 510
# Answers: 313
#
# 35: [fourBorderTrip(Org, V)]
# Nodes: 3554
# Answers: 1000
#
# 36: [fourBorderTrip(C, Region)]
# Nodes: 27443
# Answers: 1000
#
# 37: [cityInContinent(C, asia), capitalCity(C)]
# min depth: 3
# Nodes: 365
# Answers: 50
#
# 38: [sameAlliance(W, City)]
# min depth: 3
# Nodes: 1055
# Answers: 1000
#
# 39: [officialLanguage(C, spanish), sharesLanguage(venezuela, C)]
# min depth: 1
# Nodes: 21
# Answers: 20
#
# 40: [fourBorderTrip(Neighbor, W)]
# Nodes: 65517
# Answers: 1000
#
# 41: [threeBorderTrip(City, Continent)]
# min depth: 8
# Nodes: 33415
# Answers: 1000
#
# 42: [sharesLanguage(Z, Org)]
# min depth: 3
# Nodes: 1052
# Answers: 1000
#
# 43: [cityInRegion(al_wakrah, C), cityInAllianceAndRegion(mashhad, City, C), twoStepBorderNeighborAlliance(russia, City), twoStepBorderNeighborAlliance(cambodia, City)]
# min depth: 3
# Nodes: 198
# Answers: 1
#
# 44: [twoBorderTrip(C, City), sharesLanguage(C, namibia), threeBorderTrip(City, rwanda), sharesLanguage(united_kingdom, C)]
# min depth: 5
# Nodes: 1606
# Answers: 1000
#
# 45: [capitalInAllianceAndRegion(washington_dc, C, City), cityInAlliance(Continent, C), locatedIn(nicaragua, City), cityInRegion(Continent, oceania), twoStepBorderNeighborAlliance(belize, C)]
# min depth: 4
# Nodes: 8
# Answers: 4
#
# 46: [capitalCity(C), cityInRegion(C, City), capitalInAllianceAndRegion(Continent, eu, City), cityInAllianceAndRegion(C, nato, City), capitalInAllianceAndRegion(Continent, nato, City)]
# min depth: 2
# Nodes: 197
# Answers: 195
#
# 47: [sameRegion(L, Region)]
# min depth: 3
# Nodes: 1028
# Answers: 1000
#
# 48: [fourBorderTrip(Neighbor, Neighbor)]
# Nodes: 8537
# Answers: 1000
#
# 49: [twoBorderTrip(denmark, C), twoBorderTrip(C, luxembourg)]
# min depth: 5
# Nodes: 1790
# Answers: 10
#
# 50: [sharesLanguage(Continent, V)]
# min depth: 3
# Nodes: 1063
# Answers: 1000
#
# 51: [cityIn(City, C), sameRegion(C, gambia), cityInContinent(City, africa)]
# min depth: 1
# Nodes: 314
# Answers: 313
#
# 52: [threeBorderTrip(R, O)]
# min depth: 8
# Nodes: 24617
# Answers: 1000
#
# 53: [sameRegion(O, City)]
# min depth: 3
# Nodes: 1026
# Answers: 1000
#
# 54: [sameRegion(Neighbor, V)]
# min depth: 3
# Nodes: 1027
# Answers: 1000
#
# 55: [usesSameCurrency(Region, X)]
# min depth: 3
# Nodes: 1175
# Answers: 1000
#
# 56: [fourBorderTrip(L, Neighbor)]
# Nodes: 5897
# Answers: 1000
#
# 57: [currencyOf(turkey, C)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 58: [sameAlliance(Neighbor, Org)]
# min depth: 3
# Nodes: 1052
# Answers: 1000
#
# 59: [cityInAlliance(C, City), cityInRegion(C, asia), countryInAllianceAndRegion(uruguay, City, Continent), capitalInContinent(montevideo, Continent)]
# min depth: 3
# Nodes: 494
# Answers: 179
#
# 60: [capitalCity(Z)]
# min depth: 2
# Nodes: 197
# Answers: 195
#
# 61: [sharesLanguage(C, C), sharesLanguage(C, City), sameRegion(City, nepal), threeBorderTrip(City, City), threeBorderTrip(City, kyrgyzstan)]
# min depth: 3
# Nodes: 532
# Answers: 265
#
# 62: [officialLanguage(marshall_islands, C)]
# min depth: 1
# Nodes: 3
# Answers: 2
#
# 63: [sharesLanguage(X, Country)]
# min depth: 3
# Nodes: 1070
# Answers: 1000
#
# 64: [borderNeighborAlliance(Y, Region)]
# min depth: 4
# Nodes: 750
# Answers: 433
#
# 65: [sameRegion(R, City)]
# min depth: 3
# Nodes: 1027
# Answers: 1000
#
# 66: [fourBorderTrip(O, C)]
# Nodes: 3233
# Answers: 1000
#
# 67: [sharesLanguage(W, Z)]
# min depth: 3
# Nodes: 1056
# Answers: 1000
#
# 68: [cityInContinent(City, C), locatedIn(united_states, C), cityInRegion(City, C)]
# min depth: 3
# Nodes: 628
# Answers: 313
#
# 69: [currencyOf(C, City), fourBorderTrip(bulgaria, C), fourBorderTrip(armenia, C)]
# min depth: 1
# Nodes: 196
# Answers: 195
#
# 70: [sharesLanguage(Z, City)]
# min depth: 3
# Nodes: 1054
# Answers: 1000
#
# 71: [twoBorderTrip(W, Y)]
# min depth: 5
# Nodes: 1549
# Answers: 1000
#
# 72: [fourBorderTrip(Neighbor, O)]
# Nodes: 60950
# Answers: 1000
#
# 73: [threeBorderTrip(Y, W)]
# min depth: 8
# Nodes: 1570
# Answers: 1000
#
# 74: [officialLanguage(City, C), sharesLanguage(City, City)]
# min depth: 1
# Nodes: 266
# Answers: 265
#
# 75: [cityInContinent(daugavpils, C), cityInAllianceAndRegion(City, eu, C), cityInContinent(City, C)]
# min depth: 3
# Nodes: 4
# Answers: 1
#
# 76: [sameRegion(Country, O)]
# min depth: 3
# Nodes: 1030
# Answers: 1000
#
# 77: [sameRegion(Continent, C)]
# min depth: 3
# Nodes: 1027
# Answers: 1000
#
# 78: [fourBorderTrip(C, Z)]
# Nodes: 46356
# Answers: 1000
#
# 79: [cityInAlliance(L, City)]
# min depth: 3
# Nodes: 286
# Answers: 179
#
# 80: [sameRegion(City, O)]
# min depth: 3
# Nodes: 1030
# Answers: 1000
#
# 81: [sharesLanguage(X, V)]
# min depth: 3
# Nodes: 1058
# Answers: 1000
#
# 82: [threeBorderTrip(O, O)]
# min depth: 8
# Nodes: 11554
# Answers: 1000
#
# 83: [sharesLanguage(C, City), sharesLanguage(marshall_islands, C), sameRegion(City, vanuatu)]
# min depth: 3
# Nodes: 1048
# Answers: 1000
#
# 84: [currencyOf(C, City), threeBorderTrip(north_korea, C), threeBorderTrip(C, turkey)]
# min depth: 1
# Nodes: 196
# Answers: 195
#
# 85: [sharesLanguage(L, C)]
# min depth: 3
# Nodes: 1051
# Answers: 1000
#
# 86: [sameRegion(X, R)]
# min depth: 3
# Nodes: 1029
# Answers: 1000
#
# 87: [sameRegion(Y, Continent)]
# min depth: 3
# Nodes: 1033
# Answers: 1000
#
# 88: [capitalInContinent(C, City), capitalCity(C), cityInRegion(C, City), cityInRegion(monrovia, City)]
# min depth: 3
# Nodes: 392
# Answers: 195
#
# 89: [officialLanguage(City, C), sameRegion(timor_leste, City), threeBorderTrip(tajikistan, City), cityIn(kabul, City)]
# min depth: 1
# Nodes: 266
# Answers: 265
#
# 90: [fourBorderTrip(R, Y)]
# Nodes: 54509
# Answers: 1000
#
# 91: [twoStepBorderNeighborAlliance(C, brics), sharesLanguage(guatemala, C), threeBorderTrip(C, argentina), fourBorderTrip(chile, C), sameAlliance(C, ireland)]
# min depth: 7
# Nodes: 12968
# Answers: 358
#
# 92: [sameRegion(Neighbor, V)]
# min depth: 3
# Nodes: 1029
# Answers: 1000
#
# 93: [cityInAllianceAndRegion(C, g20, asia), cityInContinent(C, asia), cityInAlliance(C, g20)]
# min depth: 4
# Nodes: 381
# Answers: 16
#
# 94: [sameAlliance(V, V)]
# min depth: 3
# Nodes: 212
# Answers: 105
#
# 95: [sameAlliance(O, City)]
# min depth: 3
# Nodes: 1050
# Answers: 1000
#
# 96: [sharesLanguage(W, R)]
# min depth: 3
# Nodes: 1039
# Answers: 1000
#
# 97: [sameRegion(City, V)]
# min depth: 3
# Nodes: 1025
# Answers: 1000
#
# 98: [currencyOf(belarus, C)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 99: [currencyOf(C, south_korean_won), countryInAsia(C)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 100: [sameRegion(Country, C)]
# min depth: 3
# Nodes: 1030
# Answers: 1000
#
# Before removing duplicates: 444806 examples
# After removing duplicates: 40807 examples
# pos len=21202, neg len=21202

# %% [markdown]
# Train the scoring model. This step will usually take several minutes, especially if you are not using a GPU (for the countries_kb KB, it takes about 30 minutes on CPU).
#
# Creates a file:
# * uni_mr_model.pt - Contains the weights for the learned scoring model

# %%
# !cd countriesmod && python ../nnreasoner2.py --embed_type unification --save_model uni_mr_model.pt --embed_model_path rKB_model.pth
# Out:
# States from vocab: vocab
# Num predicates: 36
# Max arity: 3
# Num constants: 759
# Num variables: 15
#
# Training unification
# Embed size: 50
# Reading examples from mr_train_examples.csv
# Parsing examples...
# Generating embeddings...
# Embedding input size: 2358
#  [███████████████] 42403/42403 Prepping examples
# Loaded data...
# Using cuda device
# /opt/tljh/user/envs/cse327python311/lib/python3.11/site-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# 0	0.27482 (-)
# 50	0.24072 (-0.0004)
# 100	0.23723 (-0.0002)
# 150	0.23470 (-0.0001)
# 200	0.23192 (-0.0001)
# 250	0.22851 (-0.0001)
# 300	0.22379 (-0.0001)
# 350	0.21924 (-0.0001)
# 400	0.21643 (-0.0001)
# 450	0.21406 (-0.0001)
# 500	0.21259 (-0.0001)
# 550	0.21101 (-9.4291)
# 600	0.20965 (-8.8739)
# 650	0.20878 (-8.3693)
# 700	0.20788 (-7.8743)
# 749	0.20709 (-6.6911)
# Saved training loss figure.

# %%
from pathlib import Path
import matplotlib.pyplot as plt

img_paths = sorted(Path("countriesmod").glob("guided_loss*.png"))
img = plt.imread(img_paths[0])
plt.figure(figsize=(8, 5))
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# Evaluate the scoring model by running evaluate.py. We compare the standard backward-chaining algorithm (-s) with the one that uses our learned scoring model (-u).
#
# The output lists each query, and then provides a line that gives information about query execution. These are: number of nodes explored in the tree, depth of the solution, execution time in seconds, and the speed of exploring the tree (nodes per second).
#
# The names of the files produced depend on the KB used and the options selected. The code below produces the files:
#
# * std-45-106-2-50.csv - A CSV file with query results for the standard backward-chaining algorithm
# * ming-45-106-2-50.csv - A CSV file with query results for the learned reasoner. ming stands for "min scoring goal" and is the default strategy for deciding how to make use of the scores
#
# If you use a different knowledge base, you will likely get different file names that depend on the features of that KB's vocabulary.

# %%
# !cd countriesmod && python ../evaluate2.py --kb ../countries/countries_kb.txt -s 
# !cd countriesmod && python ../evaluate2.py --kb ../countries/countries_kb.txt -u --embed_model_path rKB_model.pth --scoring_model_path uni_mr_model.pt
# Out:
# using cuda device
# STANDARD
#
# Query 1: [sameRegion(Neighbor, Continent)]
# 4 :: 3 - 00:00:00 (1133 nps)
#
# Query 2: [capitalInContinent(brasilia, C), capitalInAllianceAndRegion(lima, City, C), locatedIn(uruguay, C), cityInAllianceAndRegion(amsterdam, City, europe)]
# 13 :: 12 - 00:00:00 (1075 nps)
#
# Query 3: [fourBorderTrip(Country, Y)]
# 13 :: 11 - 00:00:00 (1029 nps)
#
# Query 4: [sameRegion(X, Z)]
# 4 :: 3 - 00:00:00 (1081 nps)
#
# Query 5: [capitalOf(nicaragua, C), cityInRegion(C, north_america)]
# 5 :: 4 - 00:00:00 (948 nps)
#
# Query 6: [cityIn(vilnius, C), sameRegion(C, latvia), fourBorderTrip(C, kyrgyzstan)]
# 89 :: 15 - 00:00:00 (449 nps)
#
# Query 7: [sharesLanguage(L, W)]
# 4 :: 3 - 00:00:00 (898 nps)
#
# Query 8: [officialLanguage(bulgaria, C)]
# 2 :: 1 - 00:00:00 (1004 nps)
#
# Query 9: [fourBorderTrip(Neighbor, Z)]
# 13 :: 11 - 00:00:00 (2360 nps)
#
# Query 10: [sameRegion(L, V)]
# 4 :: 3 - 00:00:00 (1172 nps)
#
# Query 11: [sameRegion(C, azerbaijan), twoBorderTrip(C, City), threeBorderTrip(france, C), sameRegion(City, czechia)]
# Query failed!!!
# 113277 :: 0 - 00:00:03 (31210 nps)
#
# Query 12: [threeBorderTrip(O, Region)]
# 10 :: 8 - 00:00:00 (954 nps)
#
# Query 13: [fourBorderTrip(C, chile), sharesLanguage(peru, C), sharesLanguage(C, City), sharesLanguage(guatemala, City), sharesLanguage(City, dominican_republic)]
# Query failed!!!
# 57713 :: 0 - 00:00:02 (19733 nps)
#
# Query 14: [fourBorderTrip(Country, L)]
# 13 :: 11 - 00:00:00 (4781 nps)
#
# Query 15: [threeBorderTrip(City, C), twoStepBorderNeighborAlliance(C, cis), fourBorderTrip(City, Continent), fourBorderTrip(bhutan, City), sameAlliance(slovenia, Continent)]
# Query failed!!!
# 790791 :: 0 - 00:00:11 (68447 nps)
#
# Query 16: [sameRegion(Country, Continent)]
# 4 :: 3 - 00:00:00 (171 nps)
#
# Query 17: [cityIn(C, City), cityInContinent(C, europe), fourBorderTrip(bangladesh, City)]
# 3264 :: 15 - 00:00:01 (2904 nps)
#
# Query 18: [sharesLanguage(Country, Y)]
# 4 :: 3 - 00:00:00 (165 nps)
#
# Query 19: [capitalInContinent(malabo, C), capitalInContinent(niamey, C), cityInContinent(accra, C)]
# 10 :: 9 - 00:00:00 (1018 nps)
#
# Query 20: [officialLanguage(C, irish), sameRegion(liechtenstein, C)]
# 5 :: 4 - 00:00:00 (1027 nps)
#
# Query 21: [fourBorderTrip(W, City)]
# 13 :: 11 - 00:00:00 (1562 nps)
#
# Query 22: [officialLanguage(C, pashto), twoBorderTrip(nepal, C)]
# 11 :: 6 - 00:00:00 (913 nps)
#
# Query 23: [capitalInContinent(C, africa), cityIn(C, mali), cityInRegion(C, africa)]
# 186 :: 7 - 00:00:00 (626 nps)
#
# Query 24: [currencyOf(north_macedonia, C)]
# 2 :: 1 - 00:00:00 (1127 nps)
#
# Query 25: [capitalInContinent(Z, C)]
# 4 :: 3 - 00:00:00 (734 nps)
#
# Query 26: [threeBorderTrip(Org, L)]
# 10 :: 8 - 00:00:00 (1259 nps)
#
# Query 27: [usesSameCurrency(V, Neighbor)]
# 4 :: 3 - 00:00:00 (1085 nps)
#
# Query 28: [sharesLanguage(L, Country)]
# 4 :: 3 - 00:00:00 (2032 nps)
#
# Query 29: [sharesLanguage(mauritius, C), sharesLanguage(jamaica, C), fourBorderTrip(C, City), twoBorderTrip(uganda, City)]
# Query failed!!!
# 5888 :: 0 - 00:00:01 (4397 nps)
#
# Query 30: [sameRegion(liechtenstein, C), twoBorderTrip(georgia, C)]
# 169 :: 8 - 00:00:00 (929 nps)
#
# Query 31: [capitalCity(Org)]
# 3 :: 2 - 00:00:00 (400 nps)
#
# Query 32: [fourBorderTrip(C, R)]
# 13 :: 11 - 00:00:00 (4418 nps)
#
# Query 33: [capitalCity(C), cityIn(C, City), capitalOf(City, C), threeBorderTrip(estonia, City)]
# 183 :: 12 - 00:00:00 (860 nps)
#
# Query 34: [sameRegion(X, R)]
# 4 :: 3 - 00:00:00 (262 nps)
#
# Query 35: [sharesLanguage(Y, V)]
# 4 :: 3 - 00:00:00 (786 nps)
#
# Query 36: [capitalOf(C, City), sharesLanguage(C, Continent), capitalInContinent(City, north_america), threeBorderTrip(Continent, dr_congo)]
# 2082 :: 15 - 00:00:00 (3867 nps)
#
# Query 37: [fourBorderTrip(R, W)]
# 13 :: 11 - 00:00:00 (47 nps)
#
# Query 38: [sameRegion(O, C)]
# 4 :: 3 - 00:00:00 (1542 nps)
#
# Query 39: [sharesLanguage(L, C)]
# 4 :: 3 - 00:00:00 (2085 nps)
#
# Query 40: [cityInRegion(C, V)]
# 4 :: 3 - 00:00:00 (728 nps)
#
# Query 41: [sameAlliance(italy, C), sameAlliance(C, united_kingdom)]
# 7 :: 6 - 00:00:00 (1886 nps)
#
# Query 42: [sameRegion(Region, Neighbor)]
# 4 :: 3 - 00:00:00 (1073 nps)
#
# Query 43: [sharesLanguage(X, O)]
# 4 :: 3 - 00:00:00 (744 nps)
#
# Query 44: [sameRegion(C, north_korea), twoBorderTrip(City, C), threeBorderTrip(tajikistan, City)]
# Query failed!!!
# 106117 :: 0 - 00:00:20 (5256 nps)
#
# Query 45: [sameRegion(oman, C), threeBorderTrip(C, saudi_arabia), fourBorderTrip(C, City), fourBorderTrip(C, belarus), threeBorderTrip(City, City)]
# Query failed!!!
# 1386 :: 0 - 00:00:00 (2637 nps)
#
# Query 46: [cityInAllianceAndRegion(City, C, Continent), cityInAllianceAndRegion(cordoba, C, south_america), cityInContinent(City, Continent), capitalInAllianceAndRegion(City, nato, Continent), cityInAllianceAndRegion(copenhagen, nato, Continent)]
# Query failed!!!
# 1406 :: 0 - 00:00:00 (2193 nps)
#
# Query 47: [threeBorderTrip(Neighbor, O)]
# 10 :: 8 - 00:00:00 (279 nps)
#
# Query 48: [sameRegion(Y, V)]
# 4 :: 3 - 00:00:00 (39 nps)
#
# Query 49: [sameRegion(City, C), fourBorderTrip(ukraine, C), sameRegion(City, Continent), cityIn(reykjavik, Continent)]
# Query failed!!!
# 1000000 :: 0 - 00:00:18 (54280 nps)
#
# Query 50: [threeBorderTrip(Neighbor, X)]
# 10 :: 8 - 00:00:00 (1827 nps)
#
# Query 51: [sharesLanguage(R, Y)]
# 4 :: 3 - 00:00:00 (120 nps)
#
# Query 52: [cityInContinent(C, City), capitalOf(timor_leste, C), cityInContinent(male, City), capitalInContinent(jakarta, City)]
# 343 :: 10 - 00:00:00 (711 nps)
#
# Query 53: [cityInRegion(andorra_la_vella, C), cityInRegion(City, C), capitalInAlliance(City, cis)]
# 132 :: 9 - 00:00:00 (924 nps)
#
# Query 54: [sameAlliance(Region, W)]
# 4 :: 3 - 00:00:00 (586 nps)
#
# Query 55: [capitalInContinent(C, north_america), cityIn(C, barbados)]
# 87 :: 4 - 00:00:00 (518 nps)
#
# Query 56: [fourBorderTrip(City, Z)]
# 13 :: 11 - 00:00:00 (424 nps)
#
# Query 57: [sameRegion(Region, Org)]
# 4 :: 3 - 00:00:00 (751 nps)
#
# Query 58: [capitalInContinent(islamabad, C), cityInContinent(City, C), capitalInAllianceAndRegion(City, cis, C), capitalInAlliance(City, cis)]
# 259 :: 13 - 00:00:00 (1215 nps)
#
# Query 59: [fourBorderTrip(Org, Org)]
# 14 :: 11 - 00:00:00 (466 nps)
#
# Query 60: [sameAlliance(indonesia, C), sameAlliance(City, C), sameRegion(ethiopia, City), sameRegion(chad, City)]
# 287 :: 12 - 00:00:00 (4492 nps)
#
# Query 61: [capitalInAlliance(City, Neighbor)]
# 4 :: 3 - 00:00:00 (93 nps)
#
# Query 62: [sameRegion(City, C), sharesLanguage(Continent, C), fourBorderTrip(City, laos), sharesLanguage(C, solomon_islands), sharesLanguage(gambia, Continent)]
# Query failed!!!
# 1000000 :: 0 - 00:00:24 (41345 nps)
#
# Query 63: [currencyOf(C, City), threeBorderTrip(C, Continent), threeBorderTrip(slovakia, Continent)]
# Query failed!!!
# 616968 :: 0 - 00:00:11 (55377 nps)
#
# Query 64: [fourBorderTrip(L, Org)]
# 13 :: 11 - 00:00:00 (419 nps)
#
# Query 65: [cityIn(C, trinidad_and_tobago), capitalInContinent(C, north_america)]
# 5 :: 4 - 00:00:00 (947 nps)
#
# Query 66: [fourBorderTrip(O, Z)]
# 13 :: 11 - 00:00:00 (383 nps)
#
# Query 67: [fourBorderTrip(W, C)]
# 13 :: 11 - 00:00:00 (1882 nps)
#
# Query 68: [cityInRegion(sydney, C), cityInRegion(City, C), cityIn(City, new_zealand)]
# 280 :: 7 - 00:00:00 (1089 nps)
#
# Query 69: [sharesLanguage(Y, C)]
# 4 :: 3 - 00:00:00 (124 nps)
#
# Query 70: [sameAlliance(Continent, Y)]
# 4 :: 3 - 00:00:00 (1565 nps)
#
# Query 71: [currencyOf(singapore, C)]
# 2 :: 1 - 00:00:00 (1069 nps)
#
# Query 72: [currencyOf(C, kina), sharesLanguage(vanuatu, C)]
# 6 :: 4 - 00:00:00 (803 nps)
#
# Query 73: [fourBorderTrip(Z, X)]
# 13 :: 11 - 00:00:00 (1660 nps)
#
# Query 74: [twoBorderTrip(C, W)]
# 6 :: 5 - 00:00:00 (939 nps)
#
# Query 75: [sameRegion(L, R)]
# 4 :: 3 - 00:00:00 (956 nps)
#
# Query 76: [sameRegion(R, L)]
# 4 :: 3 - 00:00:00 (1027 nps)
#
# Query 77: [cityInContinent(C, asia), cityIn(C, City), fourBorderTrip(City, azerbaijan)]
# 254 :: 15 - 00:00:00 (975 nps)
#
# Query 78: [fourBorderTrip(R, C)]
# 13 :: 11 - 00:00:00 (454 nps)
#
# Query 79: [currencyOf(C, algerian_dinar), threeBorderTrip(City, C), sharesLanguage(City, benin), sharesLanguage(City, guinea)]
# 3430 :: 15 - 00:00:01 (3323 nps)
#
# Query 80: [fourBorderTrip(Region, Y)]
# 13 :: 11 - 00:00:00 (1268 nps)
#
# Query 81: [cityIn(City, C), sameRegion(C, pakistan), cityInRegion(City, asia)]
# 368 :: 7 - 00:00:00 (2357 nps)
#
# Query 82: [sharesLanguage(Region, City)]
# 4 :: 3 - 00:00:00 (142 nps)
#
# Query 83: [twoBorderTrip(C, C)]
# 7 :: 5 - 00:00:00 (1730 nps)
#
# Query 84: [sameRegion(Country, Y)]
# 4 :: 3 - 00:00:00 (948 nps)
#
# Query 85: [sameRegion(O, X)]
# 4 :: 3 - 00:00:00 (1042 nps)
#
# Query 86: [sharesLanguage(fiji, C), twoBorderTrip(C, City), sameRegion(madagascar, City), sameRegion(guinea_bissau, City), borders(C, tanzania)]
# 725 :: 15 - 00:00:00 (1746 nps)
#
# Query 87: [sameRegion(C, jamaica), sharesLanguage(C, uruguay)]
# 66 :: 6 - 00:00:00 (3003 nps)
#
# Query 88: [sharesLanguage(Y, V)]
# 4 :: 3 - 00:00:00 (1747 nps)
#
# Query 89: [cityIn(kingstown, C), sharesLanguage(City, C), sameRegion(morocco, City)]
# 207 :: 7 - 00:00:00 (1050 nps)
#
# Query 90: [cityInContinent(rabat, C), cityInContinent(oran, C), cityInContinent(City, C), capitalInContinent(City, C)]
# 184 :: 12 - 00:00:00 (1013 nps)
#
# Query 91: [sharesLanguage(Z, X)]
# 4 :: 3 - 00:00:00 (176 nps)
#
# Query 92: [officialLanguage(C, City), sharesLanguage(C, solomon_islands)]
# 43 :: 4 - 00:00:00 (860 nps)
#
# Query 93: [sharesLanguage(L, X)]
# 4 :: 3 - 00:00:00 (499 nps)
#
# Query 94: [sameRegion(City, Neighbor)]
# 4 :: 3 - 00:00:00 (1013 nps)
#
# Query 95: [cityInAlliance(V, City)]
# 4 :: 3 - 00:00:00 (834 nps)
#
# Query 96: [fourBorderTrip(C, Z)]
# 13 :: 11 - 00:00:00 (3403 nps)
#
# Query 97: [capitalInContinent(C, Continent), capitalOf(City, C), sameRegion(City, malawi), cityInRegion(port_louis, Continent), locatedIn(seychelles, Continent)]
# 532 :: 11 - 00:00:00 (875 nps)
#
# Query 98: [sameRegion(moldova, C), fourBorderTrip(bulgaria, C), sameRegion(serbia, C)]
# Query failed!!!
# 21509 :: 0 - 00:00:05 (3809 nps)
#
# Query 99: [cityIn(brazzaville, C), fourBorderTrip(City, C), twoBorderTrip(Continent, City), fourBorderTrip(benin, Continent)]
# Query failed!!!
# 528891 :: 0 - 00:00:12 (42716 nps)
#
# Query 100: [threeBorderTrip(Continent, Org)]
# 10 :: 8 - 00:00:00 (693 nps)
#
# std: 42575.78 nodes/query
# 12 queries failed
# Time to run all queries: 120.44973544999996
# using cuda device
# UNITY: ming
# 	Embedding Model: rKB_model.pth
# 	Scoring Model: uni_mr_model.pt
#
# 	Control: mingoal
# 	Rule Eval: Max Rule
# Learned Embedding: Network using cuda
# /opt/tljh/user/envs/cse327python311/lib/python3.11/site-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# Query 1: [sameRegion(Neighbor, Continent)]
# 4 :: 3 - 00:00:01 (2 nps)
#
# Query 2: [capitalInContinent(brasilia, C), capitalInAllianceAndRegion(lima, City, C), locatedIn(uruguay, C), cityInAllianceAndRegion(amsterdam, City, europe)]
# 17682 :: 12 - 00:00:04 (4112 nps)
#
# Query 3: [fourBorderTrip(Country, Y)]
# 2136 :: 11 - 00:00:16 (129 nps)
#
# Query 4: [sameRegion(X, Z)]
# 4 :: 3 - 00:00:01 (2 nps)
#
# Query 5: [capitalOf(nicaragua, C), cityInRegion(C, north_america)]
# 5 :: 4 - 00:00:01 (4 nps)
#
# Query 6: [cityIn(vilnius, C), sameRegion(C, latvia), fourBorderTrip(C, kyrgyzstan)]
# 29 :: 15 - 00:00:06 (4 nps)
#
# Query 7: [sharesLanguage(L, W)]
# 4 :: 3 - 00:00:01 (2 nps)
#
# Query 8: [officialLanguage(bulgaria, C)]
# 2 :: 1 - 00:00:00 (375 nps)
#
# Query 9: [fourBorderTrip(Neighbor, Z)]
# 1376 :: 11 - 00:00:09 (146 nps)
#
# Query 10: [sameRegion(L, V)]
# 4 :: 3 - 00:00:01 (2 nps)
#
# Query 11: [sameRegion(C, azerbaijan), twoBorderTrip(C, City), threeBorderTrip(france, C), sameRegion(City, czechia)]
# 379822 :: 14 - 00:02:41 (2357 nps)
#
# Query 12: [threeBorderTrip(O, Region)]
# 9 :: 8 - 00:00:08 (1 nps)
#
# Query 13: [fourBorderTrip(C, chile), sharesLanguage(peru, C), sharesLanguage(C, City), sharesLanguage(guatemala, City), sharesLanguage(City, dominican_republic)]
# Query failed!!!
# 654 :: 0 - 00:01:51 (5 nps)
#
# Query 14: [fourBorderTrip(Country, L)]
# 2136 :: 11 - 00:00:11 (181 nps)
#
# Query 15: [threeBorderTrip(City, C), twoStepBorderNeighborAlliance(C, cis), fourBorderTrip(City, Continent), fourBorderTrip(bhutan, City), sameAlliance(slovenia, Continent)]
# Query failed!!!
# 815 :: 0 - 00:01:15 (10 nps)
#
# Query 16: [sameRegion(Country, Continent)]
# 4 :: 3 - 00:00:01 (3 nps)
#
# Query 17: [cityIn(C, City), cityInContinent(C, europe), fourBorderTrip(bangladesh, City)]
# 25371 :: 15 - 00:00:08 (2981 nps)
#
# Query 18: [sharesLanguage(Country, Y)]
# 4 :: 3 - 00:00:01 (3 nps)
#
# Query 19: [capitalInContinent(malabo, C), capitalInContinent(niamey, C), cityInContinent(accra, C)]
# 19152 :: 9 - 00:00:03 (6209 nps)
#
# Query 20: [officialLanguage(C, irish), sameRegion(liechtenstein, C)]
# 84 :: 4 - 00:00:00 (126 nps)
#
# Query 21: [fourBorderTrip(W, City)]
# 1376 :: 11 - 00:00:08 (159 nps)
#
# Query 22: [officialLanguage(C, pashto), twoBorderTrip(nepal, C)]
# 625 :: 6 - 00:00:02 (281 nps)
#
# Query 23: [capitalInContinent(C, africa), cityIn(C, mali), cityInRegion(C, africa)]
# 29 :: 7 - 00:00:01 (28 nps)
#
# Query 24: [currencyOf(north_macedonia, C)]
# 2 :: 1 - 00:00:00 (530 nps)
#
# Query 25: [capitalInContinent(Z, C)]
# 4 :: 3 - 00:00:00 (13 nps)
#
# Query 26: [threeBorderTrip(Org, L)]
# 306 :: 8 - 00:00:00 (462 nps)
#
# Query 27: [usesSameCurrency(V, Neighbor)]
# 4 :: 3 - 00:00:00 (6 nps)
#
# Query 28: [sharesLanguage(L, Country)]
# 4 :: 3 - 00:00:00 (10 nps)
#
# Query 29: [sharesLanguage(mauritius, C), sharesLanguage(jamaica, C), fourBorderTrip(C, City), twoBorderTrip(uganda, City)]
# Query failed!!!
# 31139 :: 0 - 00:01:18 (398 nps)
#
# Query 30: [sameRegion(liechtenstein, C), twoBorderTrip(georgia, C)]
# 415 :: 8 - 00:00:01 (313 nps)
#
# Query 31: [capitalCity(Org)]
# 3 :: 2 - 00:00:00 (6 nps)
#
# Query 32: [fourBorderTrip(C, R)]
# 310 :: 11 - 00:00:07 (42 nps)
#
# Query 33: [capitalCity(C), cityIn(C, City), capitalOf(City, C), threeBorderTrip(estonia, City)]
# 58 :: 12 - 00:00:07 (8 nps)
#
# Query 34: [sameRegion(X, R)]
# 4 :: 3 - 00:00:00 (4 nps)
#
# Query 35: [sharesLanguage(Y, V)]
# 4 :: 3 - 00:00:01 (3 nps)
#
# Query 36: [capitalOf(C, City), sharesLanguage(C, Continent), capitalInContinent(City, north_america), threeBorderTrip(Continent, dr_congo)]
# 30 :: 15 - 00:00:12 (2 nps)
#
# Query 37: [fourBorderTrip(R, W)]
# 1376 :: 11 - 00:00:06 (211 nps)
#
# Query 38: [sameRegion(O, C)]
# 4 :: 3 - 00:00:00 (6 nps)
#
# Query 39: [sharesLanguage(L, C)]
# 4 :: 3 - 00:00:00 (50 nps)
#
# Query 40: [cityInRegion(C, V)]
# 4 :: 3 - 00:00:00 (8 nps)
#
# Query 41: [sameAlliance(italy, C), sameAlliance(C, united_kingdom)]
# 15 :: 6 - 00:00:00 (45 nps)
#
# Query 42: [sameRegion(Region, Neighbor)]
# 4 :: 3 - 00:00:00 (4 nps)
#
# Query 43: [sharesLanguage(X, O)]
# 4 :: 3 - 00:00:01 (3 nps)
#
# Query 44: [sameRegion(C, north_korea), twoBorderTrip(City, C), threeBorderTrip(tajikistan, City)]
# 442679 :: 15 - 00:01:47 (4132 nps)
#
# Query 45: [sameRegion(oman, C), threeBorderTrip(C, saudi_arabia), fourBorderTrip(C, City), fourBorderTrip(C, belarus), threeBorderTrip(City, City)]
# Query failed!!!
# 1000000 :: 0 - 00:04:07 (4036 nps)
#
# Query 46: [cityInAllianceAndRegion(City, C, Continent), cityInAllianceAndRegion(cordoba, C, south_america), cityInContinent(City, Continent), capitalInAllianceAndRegion(City, nato, Continent), cityInAllianceAndRegion(copenhagen, nato, Continent)]
# Query failed!!!
# 56719 :: 0 - 00:01:26 (652 nps)
#
# Query 47: [threeBorderTrip(Neighbor, O)]
# 13 :: 8 - 00:00:06 (2 nps)
#
# Query 48: [sameRegion(Y, V)]
# 4 :: 3 - 00:00:01 (3 nps)
#
# Query 49: [sameRegion(City, C), fourBorderTrip(ukraine, C), sameRegion(City, Continent), cityIn(reykjavik, Continent)]
# Query failed!!!
# 1000000 :: 0 - 00:01:30 (11097 nps)
#
# Query 50: [threeBorderTrip(Neighbor, X)]
# 9 :: 8 - 00:00:02 (4 nps)
#
# Query 51: [sharesLanguage(R, Y)]
# 4 :: 3 - 00:00:00 (5 nps)
#
# Query 52: [cityInContinent(C, City), capitalOf(timor_leste, C), cityInContinent(male, City), capitalInContinent(jakarta, City)]
# 433 :: 10 - 00:00:01 (283 nps)
#
# Query 53: [cityInRegion(andorra_la_vella, C), cityInRegion(City, C), capitalInAlliance(City, cis)]
# 564 :: 9 - 00:00:04 (117 nps)
#
# Query 54: [sameAlliance(Region, W)]
# 4 :: 3 - 00:00:00 (12 nps)
#
# Query 55: [capitalInContinent(C, north_america), cityIn(C, barbados)]
# 24 :: 4 - 00:00:00 (324 nps)
#
# Query 56: [fourBorderTrip(City, Z)]
# 1376 :: 11 - 00:00:07 (183 nps)
#
# Query 57: [sameRegion(Region, Org)]
# 4 :: 3 - 00:00:00 (6 nps)
#
# Query 58: [capitalInContinent(islamabad, C), cityInContinent(City, C), capitalInAllianceAndRegion(City, cis, C), capitalInAlliance(City, cis)]
# 11558 :: 13 - 00:00:02 (3968 nps)
#
# Query 59: [fourBorderTrip(Org, Org)]
# 9750 :: 11 - 00:00:16 (598 nps)
#
# Query 60: [sameAlliance(indonesia, C), sameAlliance(City, C), sameRegion(ethiopia, City), sameRegion(chad, City)]
# 21175 :: 11 - 00:00:04 (4329 nps)
#
# Query 61: [capitalInAlliance(City, Neighbor)]
# 4 :: 3 - 00:00:00 (24 nps)
#
# Query 62: [sameRegion(City, C), sharesLanguage(Continent, C), fourBorderTrip(City, laos), sharesLanguage(C, solomon_islands), sharesLanguage(gambia, Continent)]
# Query failed!!!
# 1000000 :: 0 - 00:05:43 (2913 nps)
#
# Query 63: [currencyOf(C, City), threeBorderTrip(C, Continent), threeBorderTrip(slovakia, Continent)]
# Query failed!!!
# 1000000 :: 0 - 00:02:34 (6453 nps)
#
# Query 64: [fourBorderTrip(L, Org)]
# 1971 :: 11 - 00:00:04 (425 nps)
#
# Query 65: [cityIn(C, trinidad_and_tobago), capitalInContinent(C, north_america)]
# 23 :: 4 - 00:00:00 (402 nps)
#
# Query 66: [fourBorderTrip(O, Z)]
# 4086 :: 11 - 00:00:03 (1308 nps)
#
# Query 67: [fourBorderTrip(W, C)]
# 1376 :: 11 - 00:00:04 (317 nps)
#
# Query 68: [cityInRegion(sydney, C), cityInRegion(City, C), cityIn(City, new_zealand)]
# 129 :: 7 - 00:00:01 (70 nps)
#
# Query 69: [sharesLanguage(Y, C)]
# 4 :: 3 - 00:00:01 (3 nps)
#
# Query 70: [sameAlliance(Continent, Y)]
# 4 :: 3 - 00:00:00 (8 nps)
#
# Query 71: [currencyOf(singapore, C)]
# 2 :: 1 - 00:00:00 (308 nps)
#
# Query 72: [currencyOf(C, kina), sharesLanguage(vanuatu, C)]
# 5 :: 4 - 00:00:00 (134 nps)
#
# Query 73: [fourBorderTrip(Z, X)]
# 1376 :: 11 - 00:00:05 (265 nps)
#
# Query 74: [twoBorderTrip(C, W)]
# 6 :: 5 - 00:00:01 (3 nps)
#
# Query 75: [sameRegion(L, R)]
# 4 :: 3 - 00:00:00 (5 nps)
#
# Query 76: [sameRegion(R, L)]
# 4 :: 3 - 00:00:00 (2747 nps)
#
# Query 77: [cityInContinent(C, asia), cityIn(C, City), fourBorderTrip(City, azerbaijan)]
# 2686 :: 15 - 00:00:15 (175 nps)
#
# Query 78: [fourBorderTrip(R, C)]
# 1376 :: 11 - 00:00:00 (4871 nps)
#
# Query 79: [currencyOf(C, algerian_dinar), threeBorderTrip(City, C), sharesLanguage(City, benin), sharesLanguage(City, guinea)]
# 11746 :: 15 - 00:00:15 (748 nps)
#
# Query 80: [fourBorderTrip(Region, Y)]
# 1376 :: 11 - 00:00:02 (590 nps)
#
# Query 81: [cityIn(City, C), sameRegion(C, pakistan), cityInRegion(City, asia)]
# 645 :: 7 - 00:00:04 (156 nps)
#
# Query 82: [sharesLanguage(Region, City)]
# 4 :: 3 - 00:00:00 (7 nps)
#
# Query 83: [twoBorderTrip(C, C)]
# 302 :: 4 - 00:00:00 (502 nps)
#
# Query 84: [sameRegion(Country, Y)]
# 4 :: 3 - 00:00:00 (4 nps)
#
# Query 85: [sameRegion(O, X)]
# 4 :: 3 - 00:00:00 (7 nps)
#
# Query 86: [sharesLanguage(fiji, C), twoBorderTrip(C, City), sameRegion(madagascar, City), sameRegion(guinea_bissau, City), borders(C, tanzania)]
# 21 :: 14 - 00:00:01 (12 nps)
#
# Query 87: [sameRegion(C, jamaica), sharesLanguage(C, uruguay)]
# 205 :: 6 - 00:00:00 (349 nps)
#
# Query 88: [sharesLanguage(Y, V)]
# 4 :: 3 - 00:00:00 (8 nps)
#
# Query 89: [cityIn(kingstown, C), sharesLanguage(City, C), sameRegion(morocco, City)]
# 8 :: 7 - 00:00:00 (14 nps)
#
# Query 90: [cityInContinent(rabat, C), cityInContinent(oran, C), cityInContinent(City, C), capitalInContinent(City, C)]
# 13 :: 12 - 00:00:00 (13 nps)
#
# Query 91: [sharesLanguage(Z, X)]
# 4 :: 3 - 00:00:00 (4 nps)
#
# Query 92: [officialLanguage(C, City), sharesLanguage(C, solomon_islands)]
# 7 :: 4 - 00:00:01 (6 nps)
#
# Query 93: [sharesLanguage(L, X)]
# 4 :: 3 - 00:00:00 (9 nps)
#
# Query 94: [sameRegion(City, Neighbor)]
# 4 :: 3 - 00:00:00 (12 nps)
#
# Query 95: [cityInAlliance(V, City)]
# 4 :: 3 - 00:00:00 (7 nps)
#
# Query 96: [fourBorderTrip(C, Z)]
# 608 :: 11 - 00:00:02 (248 nps)
#
# Query 97: [capitalInContinent(C, Continent), capitalOf(City, C), sameRegion(City, malawi), cityInRegion(port_louis, Continent), locatedIn(seychelles, Continent)]
# 771301 :: 11 - 00:07:15 (1771 nps)
#
# Query 98: [sameRegion(moldova, C), fourBorderTrip(bulgaria, C), sameRegion(serbia, C)]
# 42684 :: 15 - 00:00:37 (1140 nps)
#
# Query 99: [cityIn(brazzaville, C), fourBorderTrip(City, C), twoBorderTrip(Continent, City), fourBorderTrip(benin, Continent)]
# Query failed!!!
# 5761 :: 0 - 00:00:19 (297 nps)
#
# Query 100: [threeBorderTrip(Continent, Org)]
# 9 :: 8 - 00:00:02 (3 nps)
#
# ming: 58771.11 nodes/query
# 9 queries failed
# Time to run all queries: 2206.930834221001

# %% [markdown]
# The results suggest only minor improvements for the countries_kb KB: on average 3.75 vs. 4.39 node per query when I ran it. You may get different results due to the randomization of training and random selection of test queries. Larger, more complex KBs can see much larger improvements, sometimes an order of magnitude or more.
#
# The code below shows the first 10 lines of each query result file. A given line has:
# * query sequence number
# * configuration name
# * number of nodes explored
# * depth of solution (0 if no solution found)
# * did the system find a solution (true/false)
# * time in seconds
#
# You can import these files into a spreadsheet in order to create plots or summary statistics.

# %%
# !head std-36-759-3-50.csv
# !head ming-36-759-3-50.csv
