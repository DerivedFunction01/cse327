# %% [markdown]
# The block below imports a necessary module and checks if you are in the right directory. If you do not see a list of python files when you run the block, please make sure you have uploaded the zip file and unzipped it.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# If you want to create a random knowledge base, run the following code.
#
# Creates the files:
#
# * randomKB.txt - A random KB generated using 10 predicates and 100 constants.
# * vocab.pkl - Indexes the full set of predicates, constants and variables used by the knowledge base.

# %%
# !python kbencoder.py --generate_kb --new_vocab --save_vocab
# !head randomKB.txt

# %% [markdown]
# The following code prepares an existing knowledge base (KB) for use. To use a KB of your choosing, replace countries_kb.txt with the file name of any KB you want to use.
#
# Creates the file:
#
# *   vocab.pkl - Indexes the full set of predicates, constants and variables used by the knowledge base.

# %%
# !mkdir -p countries64

# %%
# !cd countries64 && python ../kbencoder.py --kb_path ../countries/countries_kb.txt --vocab_from_kb --save_vocab
# Out:
# Creating vocabulary from last ../countries/countries_kb.txt knowledge base

# %% [markdown]
# Train a neural net to convert first-order logic atoms into meaningful numeric vectors. We call these vectors "embeddings," and the learned model the embedding model. The code creates random atoms and then uses a mechanism known as triplet loss to place unifying atoms closer together.
#
# Creates the files:
#
# *   rKB_model.pth - Saves the learned weights for the embedding model
# *   training_loss-45-106-2-50.png - A plot of the training loss after each epoch. This file's name depends on the vocabulary of your KB: the four numbers are number of predicates, number of constants, max arity of the predicates, and the embedding size used. If you changed the KB, you'll need to look up the name in your drive and update the code block that displays this file.

# %%
# !cd countries64 && python ../kbencoder.py --kb_path ../countries/countries_kb.txt --train_unification_model --embed_size 64 --embed_model_path rKB_model_64.pth
# Out:
# Using cuda device
# Uni model embed size: 64
#  [████████████████████] 3500/3500 Anchors generated
#  [████████████████████] 70000/70000 Triplets generated
#  [████████████████████] 70000/70000 Triplet encodings
# Early stopping triggered-------------] 14.6% Epoch | [Epoch 74/500, Training Loss: 0.0259, Validation Loss: 0.4912]
# Saved model.
# Saved plot.
# unification model generated

# %%
from pathlib import Path
import matplotlib.pyplot as plt

img_paths = sorted(Path("countries64").glob("training_loss*-64.png"))
img = plt.imread(img_paths[0])
plt.figure(figsize=(8, 5))
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# Generate a set of train and test queries from your knowledge base. This will also generate the deductive closure (all facts that can be inferred) of your KB using forward-chaining.
#
# Produces the files:
#
# *  all_facts.txt - A list of all facts that can be inferred from the KB. This is used to generate queries that are guaranteed to have an answer.
# *  train_queries.txt - A set of training queries where each will have at least one answer.
# *  test_queries.txt - A set of test queries where each will have at least one answer.

# %%
# !cd countries64 && python ../kbencoder.py --kb_path ../countries/countries_kb.txt -g
# Out:
# Generating facts list...
# Forward chaining depth: 1
# New facts: 17818
# Forward chaining depth: 2
# New facts: 2254
# Forward chaining depth: 3
# New facts: 3870
# Forward chaining depth: 4
# New facts: 5176
# Forward chaining depth: 5
#
# Facts list generated
# 29118 total facts. Max depth = 4
#
# Number of queries: 200
# 100 training queries generated
# 100 testing queries generated

# %% [markdown]
# Create a training set for the scoring model. The examples will consist of goal, rule, score pairs, where a score of 1 means the rule can solve the goal, and 0 means it cannot. It runs the full set of training queries with a randomized backward-chaining process. This step can sometimes take a long time and is not able to take advantage of a GPU (with the countries_kb KB it took ~45 minutes).
#
# Creates a file:
# *  mr_train_examples.csv - Contains a line for each goal/rule/score example.

# %%
# !cd countries64 && python ../kbencoder.py --kb_path ../countries/countries_kb.txt -p
# Out:
# running training queries...
# Negative facts will be generated
# 1: [sameRegion(Org, L)]
# min depth: 3
# Nodes: 1032
# Answers: 1000
#
# 2: [cityInAlliance(dushanbe, C), twoStepBorderNeighborAlliance(City, C), fourBorderTrip(City, armenia)]
# min depth: 3
# Nodes: 108
# Answers: 1
#
# 3: [sameRegion(Z, C)]
# min depth: 3
# Nodes: 1031
# Answers: 1000
#
# 4: [twoBorderTrip(Neighbor, V)]
# min depth: 5
# Nodes: 1608
# Answers: 1000
#
# 5: [currencyOf(mongolia, C)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 6: [officialLanguage(timor_leste, C)]
# min depth: 1
# Nodes: 3
# Answers: 2
#
# 7: [sameRegion(C, cyprus), sameRegion(C, romania)]
# min depth: 3
# Nodes: 242
# Answers: 45
#
# 8: [cityInRegion(C, City), cityInContinent(C, City), cityIn(C, angola), cityInAllianceAndRegion(cape_town, g20, City)]
# min depth: 3
# Nodes: 510
# Answers: 313
#
# 9: [sameRegion(V, Org)]
# min depth: 3
# Nodes: 1029
# Answers: 1000
#
# 10: [threeBorderTrip(L, R)]
# min depth: 8
# Nodes: 29899
# Answers: 1000
#
# 11: [cityInContinent(yerevan, C), cityInContinent(copenhagen, C), cityInAllianceAndRegion(barcelona, nato, C)]
# min depth: 3
# Nodes: 4
# Answers: 1
#
# 12: [threeBorderTrip(V, O)]
# min depth: 8
# Nodes: 1699
# Answers: 1000
#
# 13: [sharesBorder(Y, Z)]
# min depth: 2
# Nodes: 595
# Answers: 592
#
# 14: [sharesLanguage(uganda, C), sharesLanguage(C, haiti)]
# min depth: 3
# Nodes: 334
# Answers: 67
#
# 15: [twoBorderTrip(R, L)]
# min depth: 5
# Nodes: 1627
# Answers: 1000
#
# 16: [currencyOf(C, Continent), sameRegion(City, C), sameRegion(C, uganda), sameRegion(burundi, City)]
# min depth: 1
# Nodes: 196
# Answers: 195
#
# 17: [sameRegion(Org, L)]
# min depth: 3
# Nodes: 1030
# Answers: 1000
#
# 18: [sameRegion(C, L)]
# min depth: 3
# Nodes: 1030
# Answers: 1000
#
# 19: [capitalOf(C, City), sameRegion(C, Continent), cityIn(City, C), sharesLanguage(Continent, Country), currencyOf(Country, namibian_dollar)]
# min depth: 1
# Nodes: 196
# Answers: 195
#
# 20: [capitalCity(C), capitalInContinent(C, City), cityInRegion(C, City), capitalInContinent(abuja, City), cityInContinent(C, City)]
# min depth: 2
# Nodes: 197
# Answers: 195
#
# 21: [fourBorderTrip(L, Z)]
# Nodes: 7181
# Answers: 1000
#
# 22: [sharesBorder(X, Region)]
# min depth: 2
# Nodes: 595
# Answers: 592
#
# 23: [currencyOf(C, Continent), sharesLanguage(C, City), sameRegion(City, mexico)]
# min depth: 1
# Nodes: 196
# Answers: 195
#
# 24: [threeBorderTrip(C, X)]
# min depth: 8
# Nodes: 1714
# Answers: 1000
#
# 25: [sameAlliance(Org, City)]
# min depth: 3
# Nodes: 1053
# Answers: 1000
#
# 26: [cityInContinent(C, africa), capitalInContinent(C, africa), cityIn(C, City), fourBorderTrip(City, mauritania), fourBorderTrip(niger, City)]
# min depth: 3
# Nodes: 128
# Answers: 73
#
# 27: [officialLanguage(City, C), sharesLanguage(City, Continent), sharesLanguage(Continent, liberia)]
# min depth: 1
# Nodes: 266
# Answers: 265
#
# 28: [usesSameCurrency(Continent, Z)]
# min depth: 3
# Nodes: 1186
# Answers: 1000
#
# 29: [officialLanguage(taiwan, C), officialLanguage(City, C), sharesLanguage(City, malta), sharesLanguage(City, australia)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 30: [cityIn(Continent, C), sharesLanguage(City, C), fourBorderTrip(C, bhutan), sameRegion(City, israel), capitalCity(Continent)]
# min depth: 1
# Nodes: 314
# Answers: 313
#
# 31: [fourBorderTrip(Country, X)]
# Nodes: 9199
# Answers: 1000
#
# 32: [fourBorderTrip(X, R)]
# Nodes: 7120
# Answers: 1000
#
# 33: [sharesLanguage(X, L)]
# min depth: 3
# Nodes: 1044
# Answers: 1000
#
# 34: [sameAlliance(C, C)]
# min depth: 3
# Nodes: 212
# Answers: 105
#
# 35: [sharesLanguage(W, O)]
# min depth: 3
# Nodes: 1049
# Answers: 1000
#
# 36: [capitalInContinent(City, C), countryInAllianceAndRegion(south_africa, g20, C), cityInRegion(City, C)]
# min depth: 3
# Nodes: 392
# Answers: 195
#
# 37: [twoBorderTrip(C, south_sudan), twoBorderTrip(C, City), fourBorderTrip(egypt, City)]
# min depth: 5
# Nodes: 1793
# Answers: 13
#
# 38: [sharesLanguage(R, L)]
# min depth: 3
# Nodes: 1051
# Answers: 1000
#
# 39: [sharesLanguage(Y, City)]
# min depth: 3
# Nodes: 1047
# Answers: 1000
#
# 40: [twoStepBorderNeighborAlliance(Z, Continent)]
# min depth: 7
# Nodes: 3603
# Answers: 1000
#
# 41: [fourBorderTrip(V, Neighbor)]
# Nodes: 1632
# Answers: 1000
#
# 42: [threeBorderTrip(Y, L)]
# min depth: 8
# Nodes: 28213
# Answers: 1000
#
# 43: [currencyOf(guinea, C)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 44: [cityInAllianceAndRegion(salalah, gcc, C), cityInContinent(mashhad, C)]
# min depth: 4
# Nodes: 13
# Answers: 1
#
# 45: [sharesLanguage(Region, W)]
# min depth: 3
# Nodes: 1049
# Answers: 1000
#
# 46: [sharesLanguage(L, X)]
# min depth: 3
# Nodes: 1048
# Answers: 1000
#
# 47: [fourBorderTrip(X, Y)]
# Nodes: 49741
# Answers: 1000
#
# 48: [threeBorderTrip(Region, Region)]
# min depth: 8
# Nodes: 12229
# Answers: 1000
#
# 49: [currencyOf(C, nakfa), fourBorderTrip(dr_congo, C), sharesLanguage(C, mauritania)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 50: [fourBorderTrip(Y, Org)]
# Nodes: 52039
# Answers: 1000
#
# 51: [usesSameCurrency(Country, R)]
# min depth: 3
# Nodes: 1169
# Answers: 1000
#
# 52: [twoBorderTrip(W, Y)]
# min depth: 5
# Nodes: 1621
# Answers: 1000
#
# 53: [twoBorderTrip(Country, Neighbor)]
# min depth: 5
# Nodes: 1602
# Answers: 1000
#
# 54: [sharesLanguage(City, Org)]
# min depth: 3
# Nodes: 1044
# Answers: 1000
#
# 55: [currencyOf(C, kuwaiti_dinar), sameRegion(C, City), fourBorderTrip(City, finland)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 56: [sharesLanguage(Z, X)]
# min depth: 3
# Nodes: 1055
# Answers: 1000
#
# 57: [capitalCity(C), cityInRegion(C, south_america)]
# min depth: 2
# Nodes: 197
# Answers: 195
#
# 58: [fourBorderTrip(Z, Y)]
# Nodes: 6074
# Answers: 1000
#
# 59: [fourBorderTrip(Z, X)]
# Nodes: 6262
# Answers: 1000
#
# 60: [cityInAlliance(Y, X)]
# min depth: 3
# Nodes: 286
# Answers: 179
#
# 61: [sameRegion(X, W)]
# min depth: 3
# Nodes: 1031
# Answers: 1000
#
# 62: [cityInContinent(C, City), cityIn(C, Continent), cityInContinent(Country, City), sameRegion(Continent, sierra_leone), capitalInContinent(Country, City)]
# min depth: 3
# Nodes: 510
# Answers: 313
#
# 63: [sharesLanguage(C, tanzania), sharesLanguage(zimbabwe, C)]
# min depth: 3
# Nodes: 10
# Answers: 6
#
# 64: [twoBorderTrip(Org, W)]
# min depth: 5
# Nodes: 1597
# Answers: 1000
#
# 65: [sharesLanguage(Y, L)]
# min depth: 3
# Nodes: 1052
# Answers: 1000
#
# 66: [sameRegion(W, City)]
# min depth: 3
# Nodes: 1032
# Answers: 1000
#
# 67: [capitalCity(C), capitalInContinent(C, africa), cityInContinent(C, africa), capitalOf(City, C), sameRegion(equatorial_guinea, City)]
# min depth: 2
# Nodes: 197
# Answers: 195
#
# 68: [sameRegion(R, Neighbor)]
# min depth: 3
# Nodes: 1034
# Answers: 1000
#
# 69: [sameAlliance(C, australia), sharesBorder(C, City), sameRegion(vietnam, C), sameRegion(bhutan, City)]
# min depth: 3
# Nodes: 78
# Answers: 71
#
# 70: [threeBorderTrip(O, Org)]
# min depth: 8
# Nodes: 1699
# Answers: 1000
#
# 71: [cityIn(C, City), capitalCity(C), sharesLanguage(City, spain)]
# min depth: 1
# Nodes: 314
# Answers: 313
#
# 72: [fourBorderTrip(O, Continent)]
# Nodes: 45790
# Answers: 1000
#
# 73: [sharesLanguage(Z, R)]
# min depth: 3
# Nodes: 1053
# Answers: 1000
#
# 74: [sameRegion(Region, Org)]
# min depth: 3
# Nodes: 1029
# Answers: 1000
#
# 75: [fourBorderTrip(C, V)]
# Nodes: 70633
# Answers: 1000
#
# 76: [sharesLanguage(Country, R)]
# min depth: 3
# Nodes: 1057
# Answers: 1000
#
# 77: [countryInAllianceAndRegion(Region, Neighbor, Continent)]
# min depth: 3
# Nodes: 212
# Answers: 105
#
# 78: [fourBorderTrip(W, V)]
# Nodes: 6617
# Answers: 1000
#
# 79: [sharesLanguage(dominica, C), sameRegion(C, tonga)]
# min depth: 3
# Nodes: 62
# Answers: 59
#
# 80: [sharesLanguage(W, Neighbor)]
# min depth: 3
# Nodes: 1048
# Answers: 1000
#
# 81: [usesSameCurrency(City, Region)]
# min depth: 3
# Nodes: 1170
# Answers: 1000
#
# 82: [threeBorderTrip(turkmenistan, C), threeBorderTrip(City, C), fourBorderTrip(City, City)]
# min depth: 8
# Nodes: 1945
# Answers: 107
#
# 83: [cityInContinent(C, africa), cityInRegion(C, africa)]
# min depth: 3
# Nodes: 388
# Answers: 73
#
# 84: [sharesLanguage(Org, Region)]
# min depth: 3
# Nodes: 1048
# Answers: 1000
#
# 85: [usesSameCurrency(Z, Country)]
# min depth: 3
# Nodes: 1123
# Answers: 926
#
# 86: [countryInAllianceAndRegion(City, Country, C), capitalInAllianceAndRegion(Continent, Country, C), usesSameCurrency(City, luxembourg), capitalInContinent(Continent, C), cityInAlliance(sofia, Country)]
# min depth: 3
# Nodes: 302
# Answers: 105
#
# 87: [sameRegion(R, Country)]
# min depth: 3
# Nodes: 1029
# Answers: 1000
#
# 88: [twoBorderTrip(R, X)]
# min depth: 5
# Nodes: 1609
# Answers: 1000
#
# 89: [fourBorderTrip(Region, X)]
# Nodes: 3468
# Answers: 1000
#
# 90: [sameRegion(Country, Z)]
# min depth: 3
# Nodes: 1034
# Answers: 1000
#
# 91: [threeBorderTrip(City, Y)]
# min depth: 8
# Nodes: 1667
# Answers: 1000
#
# 92: [currencyOf(brazil, C)]
# min depth: 1
# Nodes: 2
# Answers: 1
#
# 93: [sameRegion(R, Country)]
# min depth: 3
# Nodes: 1026
# Answers: 1000
#
# 94: [twoBorderTrip(C, bhutan), twoBorderTrip(C, City), threeBorderTrip(latvia, City), fourBorderTrip(Continent, C), sameRegion(Continent, armenia)]
# min depth: 5
# Nodes: 30
# Answers: 20
#
# 95: [fourBorderTrip(Region, Country)]
# Nodes: 1636
# Answers: 1000
#
# 96: [fourBorderTrip(O, Org)]
# Nodes: 1814
# Answers: 1000
#
# 97: [fourBorderTrip(X, R)]
# Nodes: 42765
# Answers: 1000
#
# 98: [fourBorderTrip(Neighbor, R)]
# Nodes: 1646
# Answers: 1000
#
# 99: [fourBorderTrip(R, O)]
# Nodes: 1668
# Answers: 1000
#
# 100: [twoBorderTrip(C, Neighbor)]
# min depth: 5
# Nodes: 1648
# Answers: 1000
#
# Before removing duplicates: 451373 examples
# After removing duplicates: 43971 examples
# pos len=22856, neg len=22856

# %% [markdown]
# Train the scoring model. This step will usually take several minutes, especially if you are not using a GPU (for the countries_kb KB, it takes about 30 minutes on CPU).
#
# Creates a file:
# * uni_mr_model.pt - Contains the weights for the learned scoring model

# %%
# !cd countries64 && python ../nnreasoner.py --embed_type unification --embed_size 64 --save_model uni_mr_model_64.pt --embed_model_path rKB_model_64.pth
# Out:
# States from vocab: vocab
# Num predicates: 36
# Max arity: 3
# Num constants: 759
# Num variables: 15
#
# Training unification
# Embed size: 64
# Reading examples from mr_train_examples.csv
# Parsing examples...
# Generating embeddings...
# Embedding input size: 2358
#  [███████████████] 45711/45711 Prepping examples
# Loaded data...
# Using cuda device
# /opt/tljh/user/envs/cse327python311/lib/python3.11/site-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# 0	0.27445 (-)
# 50	0.24528 (-0.0003)
# 100	0.24451 (-0.0001)
# 150	0.24233 (-0.0001)
# 195	0.24058 (-0.0001)

# %%
from pathlib import Path
import matplotlib.pyplot as plt

img_paths = sorted(Path("countries64").glob("guided_loss*-64.png"))
img = plt.imread(img_paths[0])
plt.figure(figsize=(8, 5))
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# Evaluate the scoring model by running evaluate.py. We compare the standard backward-chaining algorithm (-s) with the one that uses our learned scoring model (-u).
#
# The output lists each query, and then provides a line that gives information about query execution. These are: number of nodes explored in the tree, depth of the solution, execution time in seconds, and the speed of exploring the tree (nodes per second).
#
# The names of the files produced depend on the KB used and the options selected. The code below produces the files:
#
# * std-45-106-2-50.csv - A CSV file with query results for the standard backward-chaining algorithm
# * ming-45-106-2-50.csv - A CSV file with query results for the learned reasoner. ming stands for "min scoring goal" and is the default strategy for deciding how to make use of the scores
#
# If you use a different knowledge base, you will likely get different file names that depend on the features of that KB's vocabulary.

# %%
# !cd countries64 && python ../evaluate.py --kb ../countries/countries_kb.txt -s --embed_size 64
# !cd countries64 && python ../evaluate.py --kb ../countries/countries_kb.txt -u --embed_size 64 --embed_model_path rKB_model_64.pth --scoring_model_path uni_mr_model_64.pt

# %% [markdown]
# The results suggest only minor improvements for the countries_kb KB: on average 3.75 vs. 4.39 node per query when I ran it. You may get different results due to the randomization of training and random selection of test queries. Larger, more complex KBs can see much larger improvements, sometimes an order of magnitude or more.
#
# The code below shows the first 10 lines of each query result file. A given line has:
# * query sequence number
# * configuration name
# * number of nodes explored
# * depth of solution (0 if no solution found)
# * did the system find a solution (true/false)
# * time in seconds
#
# You can import these files into a spreadsheet in order to create plots or summary statistics.

# %%
# !head std-36-759-3-50.csv
# !head ming-36-759-3-50.csv
